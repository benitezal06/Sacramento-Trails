# %%
# Dependencies
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
trails_dropped = pd.read_csv('trails_dropped.csv')
trails_dropped = pd.DataFrame(trails_dropped)
#trails_dropped

# %%
trails_diff = trails_dropped.groupby('difficulty')

# %%
#Make new dataframes based on difficulty

# All easy trails
indexNames = trails_dropped[(trails_dropped['difficulty'] == 'Easy')].index
easyTrails = trails_dropped.iloc [indexNames]

# All easyIntermediate trails
indexNames = trails_dropped[ (trails_dropped['difficulty'] == 'Easy/Intermediate')].index
easyIntermediateTrails = trails_dropped.iloc [indexNames] 

# All intermediate trails
indexNames = trails_dropped[(trails_dropped['difficulty'] == 'Intermediate')].index
intermediateTrails = trails_dropped.iloc [indexNames]

# All intermediateDifficult trails
indexNames = trails_dropped[(trails_dropped['difficulty'] == 'Intermediate/Difficult')].index
intermediateDifficultTrails = trails_dropped.iloc [indexNames] 

# All difficult trails
indexNames = trails_dropped[(trails_dropped['difficulty'] == 'Difficult')].index
difficultTrails = trails_dropped.iloc [indexNames] 

# All extremelyDifficult trails
indexNames = trails_dropped[(trails_dropped['difficulty'] == 'Extremely Difficult')].index
extremelyDifficultTrails = trails_dropped.iloc [indexNames]

# %%
easyTrails
# Out:
#      Unnamed: 0       id                                   name       type  \
# 0             0  7021990                  Seasonal Wetland Loop       Hike
# 2             2  7023706                   Cosumnes Nature Loop       Hike
# 4             4  7027546           Traylor Ranch Bird Sanctuary       Hike
# 49           49  7018678                Armstrong Redwoods Tour       Hike
# 68           68  7051316              Richmond Marina Bay Trail       Hike
# ..          ...      ...                                    ...        ...
# 484         484  7023821                          Cemetery Loop      Trail
# 485         485  7015083         River View Trailhead Connector  Connector
# 492         492  7023719  Buttermilk Bend Trail Lower Connector  Connector
# 493         493  7023717                  Buttermilk Bend Trail      Trail
# 499         499  7023720  Buttermilk Bend Trail Upper Connector  Connector
#
#                                                summary difficulty  stars  \
# 0    A scenic loop around one of the wetland areas ...       Easy    3.5
# 2    A nature-watcher's delight that follows trails...       Easy    4.0
# 4    There are lots of birds to see and lots of loo...       Easy    2.0
# 49   A beautiful, easy hike through a "young" old-g...       Easy    4.2
# 68   Hike along the San Francisco Bay Trail (Richmo...       Easy    5.0
# ..                                                 ...        ...    ...
# 484  A short loop trail past the Kneebone Family Ce...       Easy    3.0
# 485                                                NaN       Easy    0.0
# 492                                                NaN       Easy    0.0
# 493  An easy riverside trail with bold wildflower d...       Easy    3.5
# 499                                                NaN       Easy    0.0
#
#      starVotes                   location  length  ascent  descent  high  low  \
# 0            2          Davis, California     3.1      10      -12    17   11
# 2            9       Thornton, California     4.0      88      -84    51    9
# 4            3         Loomis, California     3.2      65      -65   430  396
# 49           6    Guerneville, California     2.1     200     -199   359  252
# 68           2     El Cerrito, California     8.1      23      -23    15    9
# ..         ...                        ...     ...     ...      ...   ...  ...
# 484          1  Lake Wildwood, California     0.5      15      -22   566  544
# 485          0        Clayton, California     0.1      18        0   756  738
# 492          0  Lake Wildwood, California     0.2      72        0   644  572
# 493          4  Lake Wildwood, California     1.3     140      -69   697  594
# 499          0  Lake Wildwood, California     0.3       0     -142   847  705
#
#      longitude  latitude conditionStatus conditionDetails        conditionDate
# 0    -121.6261   38.5505         Unknown              NaN  1970-01-01 00:00:00
# 2    -121.4403   38.2657         Unknown              NaN  1970-01-01 00:00:00
# 4    -121.2058   38.8485         Unknown              NaN  1970-01-01 00:00:00
# 49   -123.0030   38.5324         Unknown              NaN  1970-01-01 00:00:00
# 68   -122.3167   37.9001         Unknown              NaN  1970-01-01 00:00:00
# ..         ...       ...             ...              ...                  ...
# 484  -121.1952   39.2917         Unknown              NaN  1970-01-01 00:00:00
# 485  -121.8633   37.9582         Unknown              NaN  1970-01-01 00:00:00
# 492  -121.1924   39.2932         Unknown              NaN  1970-01-01 00:00:00
# 493  -121.1923   39.2939         Unknown              NaN  1970-01-01 00:00:00
# 499  -121.1851   39.2959         Unknown              NaN  1970-01-01 00:00:00
#
# [107 rows x 19 columns]

# %%
#To be able and determinate the best trails based on the elevation we have to be able to categorize in ranges
#to give more options according to the phisical conditions.


age_bins = [-1,99, 199, 299, 399,499]
group_names = ["0-100", "100-200", "200-300", "300-400","400-500"]
easyTrails["Range"] = pd.cut(easyTrails["ascent"], age_bins, labels=group_names)
easyTrails
# Out:
# /Users/rubenbenitez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#      Unnamed: 0       id                                   name       type  \
# 0             0  7021990                  Seasonal Wetland Loop       Hike
# 2             2  7023706                   Cosumnes Nature Loop       Hike
# 4             4  7027546           Traylor Ranch Bird Sanctuary       Hike
# 49           49  7018678                Armstrong Redwoods Tour       Hike
# 68           68  7051316              Richmond Marina Bay Trail       Hike
# ..          ...      ...                                    ...        ...
# 484         484  7023821                          Cemetery Loop      Trail
# 485         485  7015083         River View Trailhead Connector  Connector
# 492         492  7023719  Buttermilk Bend Trail Lower Connector  Connector
# 493         493  7023717                  Buttermilk Bend Trail      Trail
# 499         499  7023720  Buttermilk Bend Trail Upper Connector  Connector
#
#                                                summary difficulty  stars  \
# 0    A scenic loop around one of the wetland areas ...       Easy    3.5
# 2    A nature-watcher's delight that follows trails...       Easy    4.0
# 4    There are lots of birds to see and lots of loo...       Easy    2.0
# 49   A beautiful, easy hike through a "young" old-g...       Easy    4.2
# 68   Hike along the San Francisco Bay Trail (Richmo...       Easy    5.0
# ..                                                 ...        ...    ...
# 484  A short loop trail past the Kneebone Family Ce...       Easy    3.0
# 485                                                NaN       Easy    0.0
# 492                                                NaN       Easy    0.0
# 493  An easy riverside trail with bold wildflower d...       Easy    3.5
# 499                                                NaN       Easy    0.0
#
#      starVotes                   location  length  ascent  descent  high  low  \
# 0            2          Davis, California     3.1      10      -12    17   11
# 2            9       Thornton, California     4.0      88      -84    51    9
# 4            3         Loomis, California     3.2      65      -65   430  396
# 49           6    Guerneville, California     2.1     200     -199   359  252
# 68           2     El Cerrito, California     8.1      23      -23    15    9
# ..         ...                        ...     ...     ...      ...   ...  ...
# 484          1  Lake Wildwood, California     0.5      15      -22   566  544
# 485          0        Clayton, California     0.1      18        0   756  738
# 492          0  Lake Wildwood, California     0.2      72        0   644  572
# 493          4  Lake Wildwood, California     1.3     140      -69   697  594
# 499          0  Lake Wildwood, California     0.3       0     -142   847  705
#
#      longitude  latitude conditionStatus conditionDetails  \
# 0    -121.6261   38.5505         Unknown              NaN
# 2    -121.4403   38.2657         Unknown              NaN
# 4    -121.2058   38.8485         Unknown              NaN
# 49   -123.0030   38.5324         Unknown              NaN
# 68   -122.3167   37.9001         Unknown              NaN
# ..         ...       ...             ...              ...
# 484  -121.1952   39.2917         Unknown              NaN
# 485  -121.8633   37.9582         Unknown              NaN
# 492  -121.1924   39.2932         Unknown              NaN
# 493  -121.1923   39.2939         Unknown              NaN
# 499  -121.1851   39.2959         Unknown              NaN
#
#            conditionDate    Range
# 0    1970-01-01 00:00:00    0-100
# 2    1970-01-01 00:00:00    0-100
# 4    1970-01-01 00:00:00    0-100
# 49   1970-01-01 00:00:00  200-300
# 68   1970-01-01 00:00:00    0-100
# ..                   ...      ...
# 484  1970-01-01 00:00:00    0-100
# 485  1970-01-01 00:00:00    0-100
# 492  1970-01-01 00:00:00    0-100
# 493  1970-01-01 00:00:00  100-200
# 499  1970-01-01 00:00:00    0-100
#
# [107 rows x 20 columns]

# %%
#after creatte the bins and categorize each trails according to the range we proceed to take the best for each range.

summary_easy_trails = easyTrails.groupby("Range")
summary_easy_trails_max = summary_easy_trails.max()
summary_easy_trails_max.reset_index(level = None, inplace = True)

# %%
#we clean the data dropping non relevant information

best_easy_elevation = summary_easy_trails_max.drop(['id',"Unnamed: 0","conditionStatus","conditionDate"],axis=1)
best_easy_elevation
# Out:
#      Range                  name   type difficulty  stars  starVotes  \
# 0    0-100        Woodland Trail  Trail       Easy    5.0        114
# 1  100-200       Waterfall Trail  Trail       Easy    4.7         28
# 2  200-300       Snell Barn Loop  Trail       Easy    4.2          6
# 3  300-400  Swinging Bridge Loop  Trail       Easy    5.0          8
# 4  400-500     Harden Lake Trail   Hike       Easy    3.0          1
#
#                       location  length  ascent  descent  high   low  \
# 0  Yosemite Valley, California     8.1      99        0  4052  3964
# 1  Yosemite Valley, California     4.4     175       -3  7200  7067
# 2     North Auburn, California     3.7     228     -199  1563  1407
# 3         Sheridan, California     4.8     392        0  4243  3974
# 4  Yosemite Valley, California     5.9     499     -499  7862  7449
#
#    longitude  latitude
# 0  -119.5875   39.2959
# 1  -119.5744   39.2939
# 2  -121.1687   38.9643
# 3  -119.6561   38.9738
# 4  -119.6489   37.8703

# %%
easyIntermediateTrails
# Out:
#      Unnamed: 0       id                          name       type  \
# 1             1  7089186                   Nature Loop       Hike
# 3             3  7016942              Lake Natoma Loop       Hike
# 7             7  7003413             Cronan Ranch Loop       Hike
# 8             8  7070912  Black Hole of Calcutta Falls       Hike
# 11           11  7089771        Foresthill Divide Loop       Hike
# ..          ...      ...                           ...        ...
# 462         462  7050603            Alan Thiesen Trail      Trail
# 465         465  7040725       Napa Solano Ridge Trail      Trail
# 468         468  7050688             Parking Connector  Connector
# 470         470  7087714            North Portal Trail      Trail
# 477         477  7040724                  Passini Road  Connector
#
#                                                summary         difficulty  \
# 1                A common loop that explores the park.  Easy/Intermediate
# 3    Hike around Lake Natoma on bike paths with an ...  Easy/Intermediate
# 7    An enjoyable hike with spectacular views of th...  Easy/Intermediate
# 8    An easy, popular, scenic trail that is great f...  Easy/Intermediate
# 11     A popular loop with hikers, runners and bikers.  Easy/Intermediate
# ..                                                 ...                ...
# 462            A clear trail that is full of wildlife.  Easy/Intermediate
# 465  A fairly easy singletrack loop encircling the ...  Easy/Intermediate
# 468                                                NaN  Easy/Intermediate
# 470  Short trail connecting trails in the Black Dia...  Easy/Intermediate
# 477                                                NaN  Easy/Intermediate
#
#      stars  starVotes                        location  length  ascent  \
# 1      5.0          1          Carmichael, California     1.6      21
# 3      4.2          9              Folsom, California    12.0     293
# 7      4.2         18  Auburn Lake Trails, California     6.2     771
# 8      4.0          5              Auburn, California     2.1     121
# 11     5.0          1  Auburn Lake Trails, California    11.2    1087
# ..     ...        ...                             ...     ...     ...
# 462    4.5          2         Alta Sierra, California     1.1     253
# 465    3.0          1                Napa, California     1.5     188
# 468    3.0          1         Alta Sierra, California     0.0       0
# 470    3.0          1             Antioch, California     0.9      24
# 477    0.0          0                Napa, California     0.3     190
#
#      descent  high   low  longitude  latitude conditionStatus  \
# 1        -20    77    69  -121.3127   38.6168         Unknown
# 3       -294   194   110  -121.1804   38.6766         Unknown
# 7       -760  1231   618  -120.9889   38.8260       All Clear
# 8       -122   701   600  -121.0400   38.9150       All Clear
# 11     -1087  1905  1578  -120.9824   38.9427         Unknown
# ..       ...   ...   ...        ...       ...             ...
# 462     -242  2405  2269  -121.0412   39.1471         Unknown
# 465     -189  1176   994  -122.2153   38.2574         Unknown
# 468      -17  2265  2248  -121.0359   39.1496         Unknown
# 470     -226   893   691  -121.8317   37.9512         Unknown
# 477        0   680   490  -122.2385   38.2689         Unknown
#
#     conditionDetails        conditionDate
# 1                NaN  1970-01-01 00:00:00
# 3                NaN  1970-01-01 00:00:00
# 7                Dry  2019-11-24 05:19:55
# 8                Dry  2020-01-25 19:34:02
# 11               NaN  1970-01-01 00:00:00
# ..               ...                  ...
# 462              NaN  1970-01-01 00:00:00
# 465              NaN  1970-01-01 00:00:00
# 468              NaN  1970-01-01 00:00:00
# 470              NaN  1970-01-01 00:00:00
# 477              NaN  1970-01-01 00:00:00
#
# [128 rows x 19 columns]

# %%
age_bins_ei = [-1,499, 999, 1499, 1999,2499,2999]
group_names_ei = ["0-500", "500-1000", "1000-1500", "1500-2000","2000-2500","2500-3000"]
easyIntermediateTrails["Range"] = pd.cut(easyIntermediateTrails["ascent"], age_bins_ei, labels=group_names_ei)
# Out:
# /Users/rubenbenitez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
summary_easyintermeadite_trails = easyIntermediateTrails.groupby("Range")
summary_easyintermediate_trails_max = summary_easyintermeadite_trails.max()
summary_easyintermediate_trails_max.reset_index(level = None, inplace = True)

# %%
best_easyintermediate_elevation = summary_easyintermediate_trails_max.drop(['id',"Unnamed: 0","conditionStatus","conditionDate"],axis=1)
best_easyintermediate_elevation
# Out:
#        Range                                           name   type  \
# 0      0-500                         Zim Zim Falls Overlook  Trail
# 1   500-1000                                  Zim Zim Falls  Trail
# 2  1000-1500                     Sierra Vista Preserve Loop  Trail
# 3  1500-2000  North Sonoma Mtn Trailhead to Sonoma Mtn Peak   Hike
# 4  2000-2500                                           None   None
# 5  2500-3000     Leavitt Meadows to Long Lakes Out-and-Back   Hike
#
#           difficulty  stars  starVotes                     location  length  \
# 0  Easy/Intermediate    5.0       70.0  Yosemite Valley, California    13.1
# 1  Easy/Intermediate    5.0       69.0  Yosemite Valley, California    18.7
# 2  Easy/Intermediate    5.0       31.0           Tahoma, California    12.3
# 3  Easy/Intermediate    3.8        6.0         Eldridge, California     9.7
# 4               None    NaN        NaN                         None     NaN
# 5  Easy/Intermediate    5.0        1.0       Bridgeport, California    22.0
#
#    ascent  descent    high     low  longitude  latitude
# 0   496.0      0.0  8720.0  8676.0  -119.5603   39.3234
# 1   996.0      0.0  8783.0  8517.0  -119.7875   39.8058
# 2  1449.0    -13.0  6624.0  6240.0  -119.8454   39.0139
# 3  1747.0  -1748.0  2363.0  1066.0  -122.6044   38.3635
# 4     NaN      NaN     NaN     NaN        NaN       NaN
# 5  2547.0  -2547.0  8620.0  7142.0  -119.5508   38.3338

# %%
#once we have the best trails for easy and easy/intermediate we merge the two tables.
df_easy = pd.merge(best_easy_elevation,best_easyintermediate_elevation, how="outer")

# %%
#we drop those None values  and crete a new column in the data frame to assign an specific color by difficulte
#this was usefull to see the diferrence in our graph.
df2_easy= df_easy.dropna(how='any')
df3_easy = pd.DataFrame(df2_easy)
df3_easy["color"]=df3_easy["difficulty"].replace(['Easy','Easy/Intermediate'],['lightgreen','darkgreen'])
df3_easy
# Out:
#         Range                                           name   type  \
# 0       0-100                                 Woodland Trail  Trail
# 1     100-200                                Waterfall Trail  Trail
# 2     200-300                                Snell Barn Loop  Trail
# 3     300-400                           Swinging Bridge Loop  Trail
# 4     400-500                              Harden Lake Trail   Hike
# 5       0-500                         Zim Zim Falls Overlook  Trail
# 6    500-1000                                  Zim Zim Falls  Trail
# 7   1000-1500                     Sierra Vista Preserve Loop  Trail
# 8   1500-2000  North Sonoma Mtn Trailhead to Sonoma Mtn Peak   Hike
# 10  2500-3000     Leavitt Meadows to Long Lakes Out-and-Back   Hike
#
#            difficulty  stars  starVotes                     location  length  \
# 0                Easy    5.0      114.0  Yosemite Valley, California     8.1
# 1                Easy    4.7       28.0  Yosemite Valley, California     4.4
# 2                Easy    4.2        6.0     North Auburn, California     3.7
# 3                Easy    5.0        8.0         Sheridan, California     4.8
# 4                Easy    3.0        1.0  Yosemite Valley, California     5.9
# 5   Easy/Intermediate    5.0       70.0  Yosemite Valley, California    13.1
# 6   Easy/Intermediate    5.0       69.0  Yosemite Valley, California    18.7
# 7   Easy/Intermediate    5.0       31.0           Tahoma, California    12.3
# 8   Easy/Intermediate    3.8        6.0         Eldridge, California     9.7
# 10  Easy/Intermediate    5.0        1.0       Bridgeport, California    22.0
#
#     ascent  descent    high     low  longitude  latitude       color
# 0     99.0      0.0  4052.0  3964.0  -119.5875   39.2959  lightgreen
# 1    175.0     -3.0  7200.0  7067.0  -119.5744   39.2939  lightgreen
# 2    228.0   -199.0  1563.0  1407.0  -121.1687   38.9643  lightgreen
# 3    392.0      0.0  4243.0  3974.0  -119.6561   38.9738  lightgreen
# 4    499.0   -499.0  7862.0  7449.0  -119.6489   37.8703  lightgreen
# 5    496.0      0.0  8720.0  8676.0  -119.5603   39.3234   darkgreen
# 6    996.0      0.0  8783.0  8517.0  -119.7875   39.8058   darkgreen
# 7   1449.0    -13.0  6624.0  6240.0  -119.8454   39.0139   darkgreen
# 8   1747.0  -1748.0  2363.0  1066.0  -122.6044   38.3635   darkgreen
# 10  2547.0  -2547.0  8620.0  7142.0  -119.5508   38.3338   darkgreen

# %%
df3_easy['name'] = df3_easy['name'].replace('Swinging Bridge Loop','Swinging Bridge')
df3_easy['name'] = df3_easy['name'].replace('Harden Lake Trail','Harden Lake')
df3_easy['name'] = df3_easy['name'].replace('Zim Zim Falls Overlook','Zim Zim Overlook')
df3_easy['name'] = df3_easy['name'].replace('Sierra Vista Preserve Loop','Sierra Vista Preserve')
df3_easy['name'] = df3_easy['name'].replace('North Sonoma Mtn Trailhead to Sonoma Mtn Peak','North Sonoma Trailhead')
df3_easy['name'] = df3_easy['name'].replace('Leavitt Meadows to Long Lakes Out-and-Back','Leavitt Meadows')
df2_easy
# Out:
#         Range                    name   type         difficulty  stars  \
# 0       0-100          Woodland Trail  Trail               Easy    5.0
# 1     100-200         Waterfall Trail  Trail               Easy    4.7
# 2     200-300         Snell Barn Loop  Trail               Easy    4.2
# 3     300-400         Swinging Bridge  Trail               Easy    5.0
# 4     400-500             Harden Lake   Hike               Easy    3.0
# 5       0-500        Zim Zim Overlook  Trail  Easy/Intermediate    5.0
# 6    500-1000           Zim Zim Falls  Trail  Easy/Intermediate    5.0
# 7   1000-1500   Sierra Vista Preserve  Trail  Easy/Intermediate    5.0
# 8   1500-2000  North Sonoma Trailhead   Hike  Easy/Intermediate    3.8
# 10  2500-3000         Leavitt Meadows   Hike  Easy/Intermediate    5.0
#
#     starVotes                     location  length  ascent  descent    high  \
# 0       114.0  Yosemite Valley, California     8.1    99.0      0.0  4052.0
# 1        28.0  Yosemite Valley, California     4.4   175.0     -3.0  7200.0
# 2         6.0     North Auburn, California     3.7   228.0   -199.0  1563.0
# 3         8.0         Sheridan, California     4.8   392.0      0.0  4243.0
# 4         1.0  Yosemite Valley, California     5.9   499.0   -499.0  7862.0
# 5        70.0  Yosemite Valley, California    13.1   496.0      0.0  8720.0
# 6        69.0  Yosemite Valley, California    18.7   996.0      0.0  8783.0
# 7        31.0           Tahoma, California    12.3  1449.0    -13.0  6624.0
# 8         6.0         Eldridge, California     9.7  1747.0  -1748.0  2363.0
# 10        1.0       Bridgeport, California    22.0  2547.0  -2547.0  8620.0
#
#        low  longitude  latitude       color
# 0   3964.0  -119.5875   39.2959  lightgreen
# 1   7067.0  -119.5744   39.2939  lightgreen
# 2   1407.0  -121.1687   38.9643  lightgreen
# 3   3974.0  -119.6561   38.9738  lightgreen
# 4   7449.0  -119.6489   37.8703  lightgreen
# 5   8676.0  -119.5603   39.3234   darkgreen
# 6   8517.0  -119.7875   39.8058   darkgreen
# 7   6240.0  -119.8454   39.0139   darkgreen
# 8   1066.0  -122.6044   38.3635   darkgreen
# 10  7142.0  -119.5508   38.3338   darkgreen

# %%
#Create the bar chart to see
plt.bar(df3_easy["name"],df3_easy["ascent"], color=df3_easy["color"], align="center")
plt.ylabel("Elevation", fontsize=14)
plt.xlabel("Trail", fontsize=14)
#plt.title("Best Easy Trail based on Elevation")
plt.figtext(.5,.9,' Easier Trails Based on Elevation', fontsize=25, ha='center')
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"]=[11, 6]
#plt.grid()
plt.savefig("Best Easy.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
intermediateTrails
# Out:
#      Unnamed: 0       id                          name   type  \
# 6             6  7018582             Hidden Falls Loop   Hike
# 10           10  7089210        Marshall Monument Loop   Hike
# 12           12  7063430  Independence Flat Trail Loop   Hike
# 14           14  7037154       Fleming Meadow Trail #8   Hike
# 16           16  7023190                 Stevens Trail   Hike
# ..          ...      ...                           ...    ...
# 487         487  7043255                   Miwok Trail  Trail
# 488         488  7015050              River View Trail  Trail
# 489         489  7015055            Stewartville Trail  Trail
# 490         490  7043254            Hardy Canyon Trail  Trail
# 496         496  7000151               Gray Pine Trail  Trail
#
#                                                summary    difficulty  stars  \
# 6    A loop with waterfalls that are tucked away an...  Intermediate    4.0
# 10                         A fun and educational loop.  Intermediate    5.0
# 12   Segment of the Mokelumne Coast to Crest Trail ...  Intermediate    5.0
# 14   Enjoy a beautiful loop in the trees in the Pol...  Intermediate    4.1
# 16   This 7.7-mile out-and-back, moderately difficu...  Intermediate    4.5
# ..                                                 ...           ...    ...
# 487                                      Needs Summary  Intermediate    4.0
# 488  A steady ridge-climb on a wide, smooth fire road.  Intermediate    3.0
# 489  An old mining and ranch road that's mostly fla...  Intermediate    3.0
# 490                                      Needs Summary  Intermediate    0.0
# 496        Spectacular scenery along a high ridgeline.  Intermediate    4.0
#
#      starVotes                   location  length  ascent  descent  high  \
# 6            9   North Auburn, California     8.6     811     -812   982
# 10           2    Placerville, California     3.5     600     -585  1263
# 12           1        Jackson, California     4.3     754     -753  1193
# 14           8  Pollock Pines, California     7.2    1018    -1024  4107
# 16          27         Colfax, California     7.7    1275    -1276  2384
# ..         ...                        ...     ...     ...      ...   ...
# 487          2          Byron, California     5.9    1859     -127  1981
# 488          1        Clayton, California     1.6     235     -207  1034
# 489          4        Clayton, California     4.9     451     -955  1130
# 490          0          Byron, California     3.1     857     -715  1059
# 496          1        Kenwood, California     2.6       9    -1399  2711
#
#       low  longitude  latitude conditionStatus  \
# 6     431  -121.1644   38.9589         Unknown
# 10    746  -120.8928   38.8016       All Clear
# 12    593  -120.7497   38.2973         Unknown
# 14   3589  -120.5452   38.7088         Unknown
# 16   1253  -120.9472   39.1056         Unknown
# ..    ...        ...       ...             ...
# 487   247  -121.7502   37.8684       All Clear
# 488   798  -121.8626   37.9567         Unknown
# 489   265  -121.8638   37.9576         Unknown
# 490   227  -121.7514   37.8676       All Clear
# 496  1321  -122.5092   38.4574         Unknown
#
#                                 conditionDetails        conditionDate
# 6                                            NaN  1970-01-01 00:00:00
# 10                                      Some Mud  2019-12-29 13:43:37
# 12                                           NaN  1970-01-01 00:00:00
# 14                                           NaN  1970-01-01 00:00:00
# 16                                           NaN  1970-01-01 00:00:00
# ..                                           ...                  ...
# 487  Some Mud - Cow abs horse poop is prominent.  2019-12-26 18:45:38
# 488                                          NaN  1970-01-01 00:00:00
# 489                                          NaN  1970-01-01 00:00:00
# 490  Some Mud - Cow abs horse poop is prominent.  2019-12-26 18:45:38
# 496                                          NaN  1970-01-01 00:00:00
#
# [154 rows x 19 columns]

# %%
age_bins_i = [-1,999, 1999, 2999,3999,4999,5999]
group_names_i = ["0-1000", "1000-2000", "2000-3000", "3000-4000","4000-5000","5000-6000"]
intermediateTrails["Range"] = pd.cut(intermediateTrails["ascent"], age_bins_i, labels=group_names_i)
# Out:
# /Users/rubenbenitez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
summary_intermeadite_trails = intermediateTrails.groupby("Range")
summary_intermediate_trails_max = summary_intermeadite_trails.max()
summary_intermediate_trails_max.reset_index(level = None, inplace = True)

# %%
best_intermediate_elevation = summary_intermediate_trails_max.drop(['id',"Unnamed: 0","conditionStatus","conditionDate"],axis=1)
best_intermediate_elevation
# Out:
#        Range                                               name   type  \
# 0     0-1000                                Zim Zim Falls Trail  Trail
# 1  1000-2000                                    Wunderlich Loop  Trail
# 2  2000-3000                                  Rancho Ridge Loop   Hike
# 3  3000-4000                               Western States Trail  Trail
# 4  4000-5000                                State Park Trifecta   Hike
# 5  5000-6000  Bay Area Ridge Trail: Table Rock and Palisades...  Trail
#
#      difficulty  stars  starVotes                     location  length  \
# 0  Intermediate    5.0         46  Yosemite Valley, California     9.4
# 1  Intermediate    5.0         48  Yosemite Valley, California    25.4
# 2  Intermediate    4.8          7  Yosemite Valley, California    19.8
# 3  Intermediate    4.7          3          Jackson, California    27.6
# 4  Intermediate    5.0          1         Saratoga, California    28.0
# 5  Intermediate    3.0          1        Calistoga, California    15.7
#
#    ascent  descent   high    low  longitude  latitude
# 0     991        0  10776  10106  -119.2721   39.4475
# 1    1982        0  10444   8918  -119.3346   39.6144
# 2    2547    -2003   9376   7897  -119.4705   38.9458
# 3    3388    -3526   1650    595  -120.7497   38.8879
# 4    4083    -4122   2639    415  -122.1291   37.2555
# 5    5552    -1641   4309    398  -122.5772   38.5892

# %%
intermediateDifficultTrails
# Out:
#      Unnamed: 0       id                                           name  \
# 5             5  7003896                      Stebbins Cold Canyon Loop
# 9             9  7019896  Training Hill to Pig Farm to Robie Trail Loop
# 18           18  7000146                             Bald Mountain Loop
# 20           20  7041523                   Mount Diablo Four Peaks Loop
# 21           21  7042934                        Mount Diablo Falls Loop
# ..          ...      ...                                            ...
# 479         479  7040721                            Lower Skyline Trail
# 481         481  7030887                      Upper Oat Hill Mine Trail
# 491         491  7015044                              Nortonville Trail
# 494         494  7051703                                  Stevens Trail
# 497         497  7015046                                    Ridge Trail
#
#       type                                            summary  \
# 5     Hike  A challenging trail with a great view of Lake ...
# 9     Hike  After climbing half of Training Hill, this mer...
# 18    Hike  Mediocre dirt roads and some singletrack trail...
# 20    Hike  This long, challenging hike visits Mount Diabl...
# 21    Hike  This rugged and scenic hike explores the water...
# ..     ...                                                ...
# 479  Trail  A mostly smooth trail under the shade of oaks ...
# 481  Trail  This trail leads aross striking volcanic forma...
# 491  Trail  An old road connecting the Nortonville and Som...
# 494  Trail                                      Needs Summary
# 497  Trail  A roller coaster, ridge-top fire road with gre...
#
#                  difficulty  stars  starVotes               location  length  \
# 5    Intermediate/Difficult    4.3         29    Winters, California     5.1
# 9    Intermediate/Difficult    4.0          4     Auburn, California     2.6
# 18   Intermediate/Difficult    4.0          9    Kenwood, California     7.0
# 20   Intermediate/Difficult    4.6         10    Clayton, California    15.4
# 21   Intermediate/Difficult    4.7         15    Clayton, California     5.4
# ..                      ...    ...        ...                    ...     ...
# 479  Intermediate/Difficult    3.0          1       Napa, California     0.9
# 481  Intermediate/Difficult    4.5          2  Calistoga, California     3.8
# 491  Intermediate/Difficult    3.0          3    Clayton, California     1.2
# 494  Intermediate/Difficult    4.0          1     Colfax, California     3.8
# 497  Intermediate/Difficult    3.7          3    Clayton, California     2.9
#
#      ascent  descent  high   low  longitude  latitude conditionStatus  \
# 5      1413    -1409  1539   231  -122.0970   38.5119         Unknown
# 9       752     -751  1358   612  -121.0399   38.9151         Unknown
# 18     1794    -1798  2726  1206  -122.5141   38.4380         Unknown
# 20     4406    -4404  3808   541  -121.9270   37.9221       All Clear
# 21     1107    -1105  1648   542  -121.9271   37.9221       All Clear
# ..      ...      ...   ...   ...        ...       ...             ...
# 479       0     -559   790   231  -122.2455   38.2717         Unknown
# 481     501     -414  2511  2202  -122.5255   38.6477         Unknown
# 491     333     -318  1091   758  -121.8644   37.9567         Unknown
# 494     127    -1271  2371  1227  -120.9471   39.1057         Unknown
# 497     213     -802  1253   580  -121.8647   37.9509         Unknown
#
#     conditionDetails        conditionDate
# 5                NaN  1970-01-01 00:00:00
# 9                NaN  1970-01-01 00:00:00
# 18               NaN  1970-01-01 00:00:00
# 20               NaN  2020-02-08 12:08:02
# 21               Dry  2020-02-15 14:28:53
# ..               ...                  ...
# 479              NaN  1970-01-01 00:00:00
# 481              NaN  1970-01-01 00:00:00
# 491              NaN  1970-01-01 00:00:00
# 494              NaN  1970-01-01 00:00:00
# 497              NaN  1970-01-01 00:00:00
#
# [79 rows x 19 columns]

# %%
age_bins_id = [-1,999, 1999, 2999,3999,4999,5999]
group_names_id = ["0-1000", "1000-2000", "2000-3000", "3000-4000","4000-5000","5000-6000"]
intermediateDifficultTrails["Range"] = pd.cut(intermediateDifficultTrails["ascent"], age_bins_id, labels=group_names_id)
# Out:
# /Users/rubenbenitez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
summary_intermeaditedi_trails = intermediateDifficultTrails.groupby("Range")
summary_intermediatedi_trails_max = summary_intermeaditedi_trails.max()
summary_intermediatedi_trails_max.reset_index(level = None, inplace = True)

# %%
best_intermediatedi_elevation = summary_intermediatedi_trails_max.drop(['id',"Unnamed: 0","conditionStatus","conditionDate"],axis=1)
best_intermediatedi_elevation
# Out:
#        Range                                      name   type  \
# 0     0-1000                       Upper Ritchey Trail  Trail
# 1  1000-2000               Wrights Lake to Grouse Lake  Trail
# 2  2000-3000  Tahoe Rim Trail - Kingsbury to Star Lake   Hike
# 3  3000-4000                  Yosemite Valley Traverse   Hike
# 4  4000-5000                   North Dome Out and Back   Hike
# 5  5000-6000                         Hetch Hetchy Loop   Hike
#
#                difficulty  stars  starVotes                     location  \
# 0  Intermediate/Difficult    5.0         22  Yosemite Valley, California
# 1  Intermediate/Difficult    5.0        251  Yosemite Valley, California
# 2  Intermediate/Difficult    5.0         49  Yosemite Valley, California
# 3  Intermediate/Difficult    5.0         45  Yosemite Valley, California
# 4  Intermediate/Difficult    4.6         10  Yosemite Valley, California
# 5  Intermediate/Difficult    4.7         11  Yosemite Valley, California
#
#    length  ascent  descent   high   low  longitude  latitude
# 0     6.9     874        0   9761  9521  -119.3705   39.4754
# 1    14.2    1999        0   9209  7498  -119.3154   39.7622
# 2    22.8    2981    -2056  10725  8921  -119.3008   39.3459
# 3    19.6    3990    -3325   7704  4035  -119.6018   37.9204
# 4    15.5    4760    -4404   7600  4030  -119.6022   37.9221
# 5    27.7    5499    -5500   7615  3777  -119.7883   37.9459

# %%
df_intermediate = pd.merge(best_intermediate_elevation,best_intermediatedi_elevation, how="outer")
#df_intermediate

# %%
df_intermediate["color"]=df_intermediate["difficulty"].replace(['Intermediate','Intermediate/Difficult'],['lightblue','darkblue'])
#df_intermediate

# %%
df_intermediate['name'] = df_intermediate['name'].replace('Zim Zim Falls Trail','Zim Zim Trail')
df_intermediate['name'] = df_intermediate['name'].replace('Wunderlich Loop','Wunderlich')
df_intermediate['name'] = df_intermediate['name'].replace('Rancho Ridge Loop','Rancho Ridge')
df_intermediate['name'] = df_intermediate['name'].replace('Western States Trail','Western States')
df_intermediate['name'] = df_intermediate['name'].replace('Upper Ritchey Trail','Upper Ritchey')
df_intermediate['name'] = df_intermediate['name'].replace('Bay Area Ridge Trail: Table Rock and Palisades Spur','Bay Area Ridge')
df_intermediate['name'] = df_intermediate['name'].replace('Upper Ritchey Trail','Upper Ritchey')
df_intermediate['name'] = df_intermediate['name'].replace('Wrights Lake to Grouse Lake','Wrights to Grouse Lake')
df_intermediate['name'] = df_intermediate['name'].replace('Tahoe Rim Trail - Kingsbury to Star Lake','Tahoe Rim')
df_intermediate
# Out:
#         Range                      name   type              difficulty  stars  \
# 0      0-1000             Zim Zim Trail  Trail            Intermediate    5.0
# 1   1000-2000                Wunderlich  Trail            Intermediate    5.0
# 2   2000-3000              Rancho Ridge   Hike            Intermediate    4.8
# 3   3000-4000            Western States  Trail            Intermediate    4.7
# 4   4000-5000       State Park Trifecta   Hike            Intermediate    5.0
# 5   5000-6000            Bay Area Ridge  Trail            Intermediate    3.0
# 6      0-1000             Upper Ritchey  Trail  Intermediate/Difficult    5.0
# 7   1000-2000    Wrights to Grouse Lake  Trail  Intermediate/Difficult    5.0
# 8   2000-3000                 Tahoe Rim   Hike  Intermediate/Difficult    5.0
# 9   3000-4000  Yosemite Valley Traverse   Hike  Intermediate/Difficult    5.0
# 10  4000-5000   North Dome Out and Back   Hike  Intermediate/Difficult    4.6
# 11  5000-6000         Hetch Hetchy Loop   Hike  Intermediate/Difficult    4.7
#
#     starVotes                     location  length  ascent  descent   high  \
# 0          46  Yosemite Valley, California     9.4     991        0  10776
# 1          48  Yosemite Valley, California    25.4    1982        0  10444
# 2           7  Yosemite Valley, California    19.8    2547    -2003   9376
# 3           3          Jackson, California    27.6    3388    -3526   1650
# 4           1         Saratoga, California    28.0    4083    -4122   2639
# 5           1        Calistoga, California    15.7    5552    -1641   4309
# 6          22  Yosemite Valley, California     6.9     874        0   9761
# 7         251  Yosemite Valley, California    14.2    1999        0   9209
# 8          49  Yosemite Valley, California    22.8    2981    -2056  10725
# 9          45  Yosemite Valley, California    19.6    3990    -3325   7704
# 10         10  Yosemite Valley, California    15.5    4760    -4404   7600
# 11         11  Yosemite Valley, California    27.7    5499    -5500   7615
#
#       low  longitude  latitude      color
# 0   10106  -119.2721   39.4475  lightblue
# 1    8918  -119.3346   39.6144  lightblue
# 2    7897  -119.4705   38.9458  lightblue
# 3     595  -120.7497   38.8879  lightblue
# 4     415  -122.1291   37.2555  lightblue
# 5     398  -122.5772   38.5892  lightblue
# 6    9521  -119.3705   39.4754   darkblue
# 7    7498  -119.3154   39.7622   darkblue
# 8    8921  -119.3008   39.3459   darkblue
# 9    4035  -119.6018   37.9204   darkblue
# 10   4030  -119.6022   37.9221   darkblue
# 11   3777  -119.7883   37.9459   darkblue

# %%
plt.bar(df_intermediate["name"],df_intermediate["ascent"], color=df_intermediate["color"], align="center")
plt.ylabel("Elevation", fontsize=14)
plt.xlabel("Trail", fontsize=14)
#plt.title("Best Intermediate Trail based on Elevation")
plt.figtext(.5,.9,'Intermediate Trails Based on Elevation', fontsize=25, ha='center')
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"]=[12,5]
#plt.grid()
plt.savefig("Best Intermediate.png")
plt.bar
# Out:
# <function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>

# %%
difficultTrails
# Out:
#      Unnamed: 0       id                                               name  \
# 36           36  7056138                            Eagle Peak Out and Back
# 39           39  7090570                                   Cache Creek Ford
# 46           46  7085300                    Rockbound Trail to Leland Lakes
# 50           50  7024572                                     Round Top Loop
# 51           51  7024997                  Pyramid Peak - Rocky Canyon Trail
# 59           59  7085746                        Ebbetts Pass to Carson Pass
# 61           61  7084337                                     Berkeley Hills
# 80           80  7045564                  Monument Peak Summit Out and Back
# 88           88  7010691                                       Mount Tallac
# 104         104  7020495                                       Rubicon Peak
# 159         159  7073355  Upper Rogue Valley - Upper High Meadow - PG&E ...
# 185         185  7075842                         Pedro Point Headlands Loop
# 206         206  7071486                                  Bigger Basin Loop
# 212         212  7084235                                Chalk Mountain Loop
# 236         236  7005207                                          Half Dome
# 237         237  7050920                         Happy Isles to Clouds Rest
# 239         239  7012515                          Yosemite Backcountry Loop
# 245         245  7084589                       Rainbow and Ruth Lakes Trail
# 307         307  7072975                               Cardiac Bypass Trail
# 382         382  7089957                              Hoosier Bar OHV Trail
# 440         440  7076871                                         Fern Falls
# 486         486  7038651                                   Blue Ridge Trail
# 495         495  7086303                              Lower Chaparral Trail
# 498         498  7086306                               Chaparral Loop Trail
#
#           type                                            summary difficulty  \
# 36        Hike  Excellent workout with great views of Mt. Diablo.  Difficult
# 39        Hike  A long trek along ridgelines, and rolling hill...  Difficult
# 46        Hike  Backpack through beautiful pine forests over r...  Difficult
# 50        Hike       A moderate scramble up a Sierra Nevada peak.  Difficult
# 51        Hike  An epic trail leading to the summit of iconic ...  Difficult
# 59        Hike  Awesome hike along the PCT that winds through ...  Difficult
# 61        Hike  One of several ways to hike the beautiful trai...  Difficult
# 80        Hike  This hike takes a combination of trails includ...  Difficult
# 88        Hike  An excellent hike with lots of variety and stu...  Difficult
# 104       Hike  A semi-secret trail leading to a rocky peak wi...  Difficult
# 159       Hike  This hike is awesome even after it has rained....  Difficult
# 185       Hike  Park has 246 acres of wilderness with spectacu...  Difficult
# 206       Hike                A big loop in Big Basin State Park.  Difficult
# 212       Hike      Good loop for training uphills and downhills.  Difficult
# 236       Hike  THE premier route in Yosemite. Hike to the top...  Difficult
# 237       Hike      Hike to Clouds Rest from the Yosemite Valley.  Difficult
# 239       Hike  An epic jaunt through the remote northern reac...  Difficult
# 245       Hike  Unmaintained trail winds up ridge with amazing...  Difficult
# 307      Trail  The Cardiac Bypass Trail must be traveled from...  Difficult
# 382      Trail                                      Needs Summary  Difficult
# 440  Connector                                                NaN  Difficult
# 486      Trail                               An epic ridge trail.  Difficult
# 495      Trail  Beautiful, difficult, and technical. Be cautio...  Difficult
# 498      Trail  This is a beautiful, albeit difficult trail al...  Difficult
#
#      stars  starVotes                        location  length  ascent  \
# 36     5.0          2               Alamo, California     4.2    1435
# 39     5.0          1           Clearlake, California    13.1    1543
# 46     5.0          1    South Lake Tahoe, California    10.4    2719
# 50     4.9          7    South Lake Tahoe, California     6.9    2162
# 51     4.8         21    South Lake Tahoe, California     6.5    3915
# 59     5.0          1    South Lake Tahoe, California    29.0    4310
# 61     5.0          1            Berkeley, California     3.5     995
# 80     3.5          2            Milpitas, California     9.8    2491
# 88     4.8         51    South Lake Tahoe, California     9.9    3266
# 104    5.0          8              Tahoma, California     3.6    2087
# 159    4.0          3              Loyola, California    10.4    1552
# 185    5.0          1            Pacifica, California     2.3     481
# 206    4.0          2       Boulder Creek, California    28.1    4132
# 212    4.0          2           Brookdale, California    16.9    2767
# 236    4.9        187     Yosemite Valley, California    14.5    4457
# 237    5.0          3     Yosemite Valley, California    18.3    5782
# 239    5.0          3     Yosemite Valley, California    60.6   10264
# 245    3.0          1     Yosemite Valley, California     1.8     562
# 307    3.0          2              Auburn, California     1.7      47
# 382    0.0          0  Auburn Lake Trails, California     1.3       0
# 440    0.0          0        Green Valley, California     0.3      57
# 486    4.0          1  Hidden Valley Lake, California     8.4     880
# 495    3.0          1             Clayton, California     0.3       0
# 498    3.0          1             Clayton, California     0.9     211
#
#      descent   high   low  longitude  latitude conditionStatus  \
# 36     -1434   1791   356  -122.0259   37.8340       All Clear
# 39     -2288   2208   903  -122.4158   39.0086         Unknown
# 46     -1528   8540  6967  -120.2391   38.8482         Unknown
# 50     -2162  10338  8201  -120.0094   38.6916         Unknown
# 51     -3913   9879  5964  -120.1359   38.8086         Unknown
# 59     -4446   9121  7769  -119.8116   38.5446         Unknown
# 61      -161   1355   467  -122.2440   37.8626         Unknown
# 80     -2492   2590   384  -121.9083   37.5043    Minor Issues
# 88     -3266   9712  6446  -120.0682   38.9214         Unknown
# 104    -2085   9019  6932  -120.1234   39.0103         Unknown
# 159    -1548   1580   344  -122.0880   37.3329         Unknown
# 185     -481    630   274  -122.5079   37.5850         Unknown
# 206    -4142   1724    13  -122.2229   37.1731         Unknown
# 212    -2767   1569    18  -122.2796   37.0971       All Clear
# 236    -4457   8476  4083  -119.5583   37.7325       All Clear
# 237    -5782   9729  4047  -119.5581   37.7324         Unknown
# 239   -10264  10100  4368  -119.3344   37.8776         Unknown
# 245     -111   9369  8900  -119.3529   37.5765         Unknown
# 307     -542   1372   843  -121.0673   38.8727         Unknown
# 382     -995   1690   695  -120.9771   38.9412         Unknown
# 440       -6    269   214  -122.1481   38.2454         Unknown
# 486    -2978   3012   589  -122.2896   38.8420         Unknown
# 495     -270   1042   772  -121.8650   37.9523         Unknown
# 498     -381   1169   806  -121.8687   37.9535         Unknown
#
#          conditionDetails        conditionDate
# 36             Mostly Dry  2020-01-20 16:02:23
# 39                    NaN  1970-01-01 00:00:00
# 46                    NaN  1970-01-01 00:00:00
# 50                    NaN  1970-01-01 00:00:00
# 51                    NaN  1970-01-01 00:00:00
# 59                    NaN  1970-01-01 00:00:00
# 61                    NaN  1970-01-01 00:00:00
# 80                    NaN  2020-01-20 16:59:12
# 88                    NaN  1970-01-01 00:00:00
# 104                   NaN  1970-01-01 00:00:00
# 159                   NaN  1970-01-01 00:00:00
# 185                   NaN  1970-01-01 00:00:00
# 206                   NaN  1970-01-01 00:00:00
# 212  Mostly Dry, Some Mud  2020-01-19 17:23:25
# 236                   NaN  2019-11-17 23:03:06
# 237                   NaN  1970-01-01 00:00:00
# 239                   NaN  1970-01-01 00:00:00
# 245                   NaN  1970-01-01 00:00:00
# 307                   NaN  1970-01-01 00:00:00
# 382                   NaN  1970-01-01 00:00:00
# 440                   NaN  1970-01-01 00:00:00
# 486                   NaN  1970-01-01 00:00:00
# 495                   NaN  1970-01-01 00:00:00
# 498                   NaN  1970-01-01 00:00:00

# %%
age_bins_d = [-1,1999, 3999,5999,7999,9999,11999 ]
group_names_d = ["0-2000", "2000-4000", "4000-6000","6000-8000", "8000-10000","10000-12000"]
difficultTrails["Range"] = pd.cut(difficultTrails["ascent"], age_bins_d, labels=group_names_d)
# Out:
# /Users/rubenbenitez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
summary_difficulty_trails = difficultTrails.groupby("Range")
summary_difficulty_trails_max = summary_difficulty_trails.max()
summary_difficulty_trails_max.reset_index(level = None, inplace = True)

# %%
best_difficulty_elevation = summary_difficulty_trails_max.drop(['id',"Unnamed: 0","conditionStatus","conditionDate"],axis=1)
best_difficulty_elevation
# Out:
#          Range                                               name   type  \
# 0       0-2000  Upper Rogue Valley - Upper High Meadow - PG&E ...  Trail
# 1    2000-4000                                       Rubicon Peak   Hike
# 2    4000-6000                         Happy Isles to Clouds Rest   Hike
# 3    6000-8000                                               None   None
# 4   8000-10000                                               None   None
# 5  10000-12000                          Yosemite Backcountry Loop   Hike
#
#   difficulty  stars  starVotes                     location  length   ascent  \
# 0  Difficult    5.0        3.0  Yosemite Valley, California    13.1   1552.0
# 1  Difficult    5.0       51.0           Tahoma, California    16.9   3915.0
# 2  Difficult    5.0      187.0  Yosemite Valley, California    29.0   5782.0
# 3       None    NaN        NaN                         None     NaN      NaN
# 4       None    NaN        NaN                         None     NaN      NaN
# 5  Difficult    5.0        3.0  Yosemite Valley, California    60.6  10264.0
#
#    descent     high     low  longitude  latitude
# 0     -6.0   9369.0  8900.0  -119.3529   39.0086
# 1  -1528.0  10338.0  8201.0  -120.0094   39.0103
# 2  -4142.0   9729.0  7769.0  -119.5581   38.5446
# 3      NaN      NaN     NaN        NaN       NaN
# 4      NaN      NaN     NaN        NaN       NaN
# 5 -10264.0  10100.0  4368.0  -119.3344   37.8776

# %%
df_difficult= best_difficulty_elevation.dropna(how='any')
df2_difficult = pd.DataFrame(df_difficult)
df2_difficult["color"]=df2_difficult["difficulty"].replace(['Difficult'],['darkslategrey'])
df2_difficult
# Out:
#          Range                                               name   type  \
# 0       0-2000  Upper Rogue Valley - Upper High Meadow - PG&E ...  Trail
# 1    2000-4000                                       Rubicon Peak   Hike
# 2    4000-6000                         Happy Isles to Clouds Rest   Hike
# 5  10000-12000                          Yosemite Backcountry Loop   Hike
#
#   difficulty  stars  starVotes                     location  length   ascent  \
# 0  Difficult    5.0        3.0  Yosemite Valley, California    13.1   1552.0
# 1  Difficult    5.0       51.0           Tahoma, California    16.9   3915.0
# 2  Difficult    5.0      187.0  Yosemite Valley, California    29.0   5782.0
# 5  Difficult    5.0        3.0  Yosemite Valley, California    60.6  10264.0
#
#    descent     high     low  longitude  latitude          color
# 0     -6.0   9369.0  8900.0  -119.3529   39.0086  darkslategrey
# 1  -1528.0  10338.0  8201.0  -120.0094   39.0103  darkslategrey
# 2  -4142.0   9729.0  7769.0  -119.5581   38.5446  darkslategrey
# 5 -10264.0  10100.0  4368.0  -119.3344   37.8776  darkslategrey

# %%
df2_difficult['name'] = df2_difficult['name'].replace('Upper Rogue Valley - Upper High Meadow - PG&E Loop','Rogue Valley')
df2_difficult['name'] = df2_difficult['name'].replace('Yosemite Backcountry Loop','Yosemite Backcountry')
df2_difficult['name'] = df2_difficult['name'].replace('Happy Isles to Clouds Rest','Happy Isles to Clouds')

# %%
plt.bar(df_difficult["name"],df_difficult["ascent"], color=df_difficult["color"], align="center")
plt.ylabel("Elevation", fontsize=14)
plt.xlabel("Trail", fontsize=14)
#plt.title("Best Intermediate Trail based on Elevation")
plt.figtext(.5,.9,'Difficults Trails Based on Elevation', fontsize=25, ha='center')
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"]=[10,8]
plt.savefig("Best Difficult.png")

plt.bar
# Out:
# <function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>

# %%
df_summary = pd.merge(df2_easy,df_intermediate,how = "outer")
df_final = pd.merge(df_summary,df2_difficult, how = 'outer')
df_final

# %%
df_final.to_csv('Best_trails_elevation.csv')

# %%
df_final1 = df_final.groupby('location')
df_final1.count()
# Out:
#                              Range  name  type  difficulty  stars  starVotes  \
# location
# Bridgeport, California           1     1     1           1      1          1
# Calistoga, California            1     1     1           1      1          1
# Eldridge, California             1     1     1           1      1          1
# Jackson, California              1     1     1           1      1          1
# North Auburn, California         1     1     1           1      1          1
# Saratoga, California             1     1     1           1      1          1
# Sheridan, California             1     1     1           1      1          1
# Tahoma, California               2     2     2           2      2          2
# Yosemite Valley, California     17    17    17          17     17         17
#
#                              length  ascent  descent  high  low  longitude  \
# location
# Bridgeport, California            1       1        1     1    1          1
# Calistoga, California             1       1        1     1    1          1
# Eldridge, California              1       1        1     1    1          1
# Jackson, California               1       1        1     1    1          1
# North Auburn, California          1       1        1     1    1          1
# Saratoga, California              1       1        1     1    1          1
# Sheridan, California              1       1        1     1    1          1
# Tahoma, California                2       2        2     2    2          2
# Yosemite Valley, California      17      17       17    17   17         17
#
#                              latitude  color
# location
# Bridgeport, California              1      1
# Calistoga, California               1      1
# Eldridge, California                1      1
# Jackson, California                 1      1
# North Auburn, California            1      1
# Saratoga, California                1      1
# Sheridan, California                1      1
# Tahoma, California                  2      2
# Yosemite Valley, California        17     17

# %%
df_final2 = df_final.sort_values(by=['location'], ascending=False)
df_final2.head()
# Out:
#         Range                   name   type              difficulty  stars  \
# 0       0-100         Woodland Trail  Trail                    Easy    5.0
# 12  2000-3000           Rancho Ridge   Hike            Intermediate    4.8
# 24  4000-6000  Happy Isles to Clouds   Hike               Difficult    5.0
# 22     0-2000           Rogue Valley  Trail               Difficult    5.0
# 21  5000-6000      Hetch Hetchy Loop   Hike  Intermediate/Difficult    4.7
#
#     starVotes                     location  length  ascent  descent    high  \
# 0       114.0  Yosemite Valley, California     8.1    99.0      0.0  4052.0
# 12        7.0  Yosemite Valley, California    19.8  2547.0  -2003.0  9376.0
# 24      187.0  Yosemite Valley, California    29.0  5782.0  -4142.0  9729.0
# 22        3.0  Yosemite Valley, California    13.1  1552.0     -6.0  9369.0
# 21       11.0  Yosemite Valley, California    27.7  5499.0  -5500.0  7615.0
#
#        low  longitude  latitude          color
# 0   3964.0  -119.5875   39.2959     lightgreen
# 12  7897.0  -119.4705   38.9458      lightblue
# 24  7769.0  -119.5581   38.5446  darkslategrey
# 22  8900.0  -119.3529   39.0086  darkslategrey
# 21  3777.0  -119.7883   37.9459       darkblue
