# %% [markdown]
# <h1>Sacramento's Best Trails</h1>
# <h2>Data Cleanup and Exploration</h2>
# <em>brought to you by:</em> Joy, Ruben, and Nancy

# %% [markdown]
# > #### Data Availability
# >
# > - Limited number of available trail specific and **free** APIs.
# > - Decided to use REI Hiking Project API.
# >
# >  *Caveat* is this dataset is small, so this may not be the most representative sample. Proceed with caution.

# %% [markdown]
# <h2>Step 1: What kinds of data can we pull from the API?</h2>
# (i.e. explore API documentation)

# %% [markdown]
# Hiking Project API:
# <https://www.hikingproject.com/data>

# %%
# Dependencies
import requests
import pandas as pd
from config import api_key

url = "https://www.hikingproject.com/data/get-trails?"

# %% [markdown]
# Based on documentation, we then adjust our query parameters for information on trails within 150 miles of Sacramento, CA.

# %%
lat = 38.5816
lon = -121.4944
maxDistance = 150
key = api_key

# %%
# Query
query_url = f"{url}lat={lat}&lon={lon}&maxDistance={maxDistance}&key={key}"
query_url
# Out:
# 'https://www.hikingproject.com/data/get-trails?lat=38.5816&lon=-121.4944&maxDistance=150&key=200684868-72bf127ca9e9ba5924d3b7d37a05d12c'

# %%
# Request data
data = requests.get(query_url).json()

# %%
data
# Out:
# {'trails': [{'id': 7005207,
#    'name': 'Half Dome',
#    'type': 'Hike',
#    'summary': 'THE premier route in Yosemite. Hike to the top of the most iconic granite dome in the USA.',
#    'difficulty': 'black',
#    'stars': 4.9,
#    'starVotes': 187,
#    'location': 'Yosemite Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7005207/half-dome',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003987_sqsmall_1554236134.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003987_small_1554236134.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003987_smallMed_1554236134.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003987_medium_1554236134.jpg',
#    'length': 14.5,
#    'ascent': 4457,
#    'descent': -4457,
#    'high': 8476,
#    'low': 4083,
#    'longitude': -119.5583,
#    'latitude': 37.7325,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-11-17 23:03:06'},
#   {'id': 7004777,
#    'name': 'Vernal and Nevada Falls Loop',
#    'type': 'Hike',
#    'summary': "A splendid loop past two of Yosemite's most powerful cascades.",
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 251,
#    'location': 'Yosemite Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7004777/vernal-and-nevada-falls-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003987_sqsmall_1554236134.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003987_small_1554236134.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003987_smallMed_1554236134.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003987_medium_1554236134.jpg',
#    'length': 6.2,
#    'ascent': 1999,
#    'descent': -1998,
#    'high': 6022,
#    'low': 4048,
#    'longitude': -119.5583,
#    'latitude': 37.7326,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Snowy, Icy - Some icy sections on JMT but relatively clear. JMT above Clark Point is closed',
#    'conditionDate': '2020-02-11 08:51:00'},
#   {'id': 7004501,
#    'name': 'Lower Yosemite Fall Trail',
#    'type': 'Hike',
#    'summary': 'Revel in stunning views of Yosemite Falls in its entirety and walk to the base of the Lower Fall.',
#    'difficulty': 'green',
#    'stars': 4.4,
#    'starVotes': 114,
#    'location': 'Yosemite Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7004501/lower-yosemite-fall-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003948_sqsmall_1554236020.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003948_small_1554236020.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003948_smallMed_1554236020.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003948_medium_1554236020.jpg',
#    'length': 1,
#    'ascent': 75,
#    'descent': -84,
#    'high': 4033,
#    'low': 3964,
#    'longitude': -119.5962,
#    'latitude': 37.7464,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7001511,
#    'name': 'Tomales Point Trail',
#    'type': 'Hike',
#    'summary': 'A trail with spectacular coastal views and probable elk sightings.',
#    'difficulty': 'greenBlue',
#    'stars': 4.6,
#    'starVotes': 69,
#    'location': 'Inverness, California',
#    'url': 'https://www.hikingproject.com/trail/7001511/tomales-point-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7057504_sqsmall_1555947224.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7057504_small_1555947224.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7057504_smallMed_1555947224.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7057504_medium_1555947224.jpg',
#    'length': 9.8,
#    'ascent': 996,
#    'descent': -996,
#    'high': 534,
#    'low': 83,
#    'longitude': -122.9543,
#    'latitude': 38.1891,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry',
#    'conditionDate': '2020-01-27 15:29:26'},
#   {'id': 7027132,
#    'name': 'Steep Ravine - Matt Davis Loop',
#    'type': 'Hike',
#    'summary': 'This awesome loop takes you up a redwood canyon and then down sunny slopes overlooking the Pacific.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 55,
#    'location': 'Bolinas, California',
#    'url': 'https://www.hikingproject.com/trail/7027132/steep-ravine-matt-davis-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7055144_sqsmall_1555708413.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7055144_small_1555708413.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7055144_smallMed_1555708413.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7055144_medium_1555708413.jpg',
#    'length': 7.1,
#    'ascent': 1556,
#    'descent': -1589,
#    'high': 1583,
#    'low': 81,
#    'longitude': -122.6359,
#    'latitude': 37.8966,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2020-01-20 19:12:35'},
#   {'id': 7018036,
#    'name': 'Clouds Rest Viewpoint Trail',
#    'type': 'Hike',
#    'summary': 'Incredibly stupendous side-on views of Half Dome are the highlight of this hike.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 49,
#    'location': 'Yosemite Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7018036/clouds-rest-viewpoint-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7018146_sqsmall_1554830392.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7018146_small_1554830392.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7018146_smallMed_1554830392.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7018146_medium_1554830392.jpg',
#    'length': 12.4,
#    'ascent': 2129,
#    'descent': -2130,
#    'high': 9765,
#    'low': 8157,
#    'longitude': -119.47,
#    'latitude': 37.8257,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7010691,
#    'name': 'Mount Tallac',
#    'type': 'Hike',
#    'summary': 'An excellent hike with lots of variety and stunning views.',
#    'difficulty': 'black',
#    'stars': 4.8,
#    'starVotes': 51,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7010691/mount-tallac',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7007938_sqsmall_1554323883.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7007938_small_1554323883.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7007938_smallMed_1554323883.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7007938_medium_1554323883.jpg',
#    'length': 9.9,
#    'ascent': 3266,
#    'descent': -3266,
#    'high': 9712,
#    'low': 6446,
#    'longitude': -120.0682,
#    'latitude': 38.9214,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7009377,
#    'name': 'Sentinel Dome',
#    'type': 'Hike',
#    'summary': 'An easy trail with some great westward sunset views on top of the dome.',
#    'difficulty': 'greenBlue',
#    'stars': 4.7,
#    'starVotes': 55,
#    'location': 'Yosemite Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7009377/sentinel-dome',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004023_sqsmall_1554236250.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7004023_small_1554236250.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004023_smallMed_1554236250.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7004023_medium_1554236250.jpg',
#    'length': 2.1,
#    'ascent': 350,
#    'descent': -349,
#    'high': 8065,
#    'low': 7715,
#    'longitude': -119.5867,
#    'latitude': 37.7129,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7004770,
#    'name': 'Mirror Lake Loop',
#    'type': 'Hike',
#    'summary': 'A beautiful loop through Tenaya Canyon.',
#    'difficulty': 'greenBlue',
#    'stars': 3.9,
#    'starVotes': 70,
#    'location': 'Yosemite Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7004770/mirror-lake-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003961_sqsmall_1554236057.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003961_small_1554236057.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003961_smallMed_1554236057.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003961_medium_1554236057.jpg',
#    'length': 4.7,
#    'ascent': 290,
#    'descent': -289,
#    'high': 4160,
#    'low': 3997,
#    'longitude': -119.5603,
#    'latitude': 37.7393,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7007647,
#    'name': 'Coastal Trail: Lands End',
#    'type': 'Hike',
#    'summary': 'A mega-popular hike hitting many Bay Area attractions in one fell swoop.',
#    'difficulty': 'greenBlue',
#    'stars': 4.5,
#    'starVotes': 56,
#    'location': 'San Francisco, California',
#    'url': 'https://www.hikingproject.com/trail/7007647/coastal-trail-lands-end',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7013808_sqsmall_1554823419.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7013808_small_1554823419.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7013808_smallMed_1554823419.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7013808_medium_1554823419.jpg',
#    'length': 2.9,
#    'ascent': 192,
#    'descent': -192,
#    'high': 260,
#    'low': 159,
#    'longitude': -122.5117,
#    'latitude': 37.7807,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'}],
#  'success': 1}

# %% [markdown]
# <h2> Step 2: Modify request to API based on research needs </h2>

# %%
len(data["trails"])
# Out:
# 10

# %% [markdown]
# >Uh oh. Looks like the query defaults to 10 trails.
# >Let's fix that by adding a "maxResults" parameter to the query.
# >
# >And while we are at it, include sorting based on distance from Sacramento!

# %%
lat = 38.5816
lon = -121.4944
maxDistance = 150
maxResults = 500
sort = 'distance'
key = api_key

# %%
# Query
query_url = f"{url}lat={lat}&lon={lon}&maxDistance={maxDistance}&maxResults={maxResults}&sort={sort}&key={key}"
query_url
# Out:
# 'https://www.hikingproject.com/data/get-trails?lat=38.5816&lon=-121.4944&maxDistance=150&maxResults=500&sort=distance&key=200684868-72bf127ca9e9ba5924d3b7d37a05d12c'

# %%
# Request data
data = requests.get(query_url).json()

# %%
data
# Out:
# {'trails': [{'id': 7021990,
#    'name': 'Seasonal Wetland Loop',
#    'type': 'Hike',
#    'summary': 'A scenic loop around one of the wetland areas in Yolo Basin on a wide path with wildlife viewing.',
#    'difficulty': 'green',
#    'stars': 3.5,
#    'starVotes': 2,
#    'location': 'Davis, California',
#    'url': 'https://www.hikingproject.com/trail/7021990/seasonal-wetland-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7063351_sqsmall_1569428182.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7063351_small_1569428182.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7063351_smallMed_1569428182.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7063351_medium_1569428182.jpg',
#    'length': 3.1,
#    'ascent': 10,
#    'descent': -12,
#    'high': 17,
#    'low': 11,
#    'longitude': -121.6261,
#    'latitude': 38.5505,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7089186,
#    'name': 'Nature Loop',
#    'type': 'Hike',
#    'summary': 'A common loop that explores the park.',
#    'difficulty': 'greenBlue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Carmichael, California',
#    'url': 'https://www.hikingproject.com/trail/7089186/nature-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7065291_sqsmall_1575658110.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7065291_small_1575658110.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7065291_smallMed_1575658110.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7065291_medium_1575658110.jpg',
#    'length': 1.6,
#    'ascent': 21,
#    'descent': -20,
#    'high': 77,
#    'low': 69,
#    'longitude': -121.3127,
#    'latitude': 38.6168,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7023706,
#    'name': 'Cosumnes Nature Loop',
#    'type': 'Hike',
#    'summary': "A nature-watcher's delight that follows trails through the Cosumnes River Preserve.",
#    'difficulty': 'green',
#    'stars': 4,
#    'starVotes': 9,
#    'location': 'Thornton, California',
#    'url': 'https://www.hikingproject.com/trail/7023706/cosumnes-nature-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7057450_sqsmall_1555947093.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7057450_small_1555947093.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7057450_smallMed_1555947093.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7057450_medium_1555947093.jpg',
#    'length': 4,
#    'ascent': 88,
#    'descent': -84,
#    'high': 51,
#    'low': 9,
#    'longitude': -121.4403,
#    'latitude': 38.2657,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016942,
#    'name': 'Lake Natoma Loop',
#    'type': 'Hike',
#    'summary': 'Hike around Lake Natoma on bike paths with an option for singletrack.',
#    'difficulty': 'greenBlue',
#    'stars': 4.2,
#    'starVotes': 9,
#    'location': 'Folsom, California',
#    'url': 'https://www.hikingproject.com/trail/7016942/lake-natoma-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7016940_sqsmall_1554828576.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7016940_small_1554828576.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7016940_smallMed_1554828576.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7016940_medium_1554828576.jpg',
#    'length': 12,
#    'ascent': 293,
#    'descent': -294,
#    'high': 194,
#    'low': 110,
#    'longitude': -121.1804,
#    'latitude': 38.6766,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7027546,
#    'name': 'Traylor Ranch Bird Sanctuary',
#    'type': 'Hike',
#    'summary': 'There are lots of birds to see and lots of loop trails to make your own path through the sanctuary.',
#    'difficulty': 'green',
#    'stars': 2,
#    'starVotes': 3,
#    'location': 'Loomis, California',
#    'url': 'https://www.hikingproject.com/trail/7027546/traylor-ranch-bird-sanctuary',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7044187_sqsmall_1555109775.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7044187_small_1555109775.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7044187_smallMed_1555109775.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7044187_medium_1555109775.jpg',
#    'length': 3.2,
#    'ascent': 65,
#    'descent': -65,
#    'high': 430,
#    'low': 396,
#    'longitude': -121.2058,
#    'latitude': 38.8485,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7003896,
#    'name': 'Stebbins Cold Canyon Loop',
#    'type': 'Hike',
#    'summary': 'A challenging trail with a great view of Lake Berryessa from the top.',
#    'difficulty': 'blueBlack',
#    'stars': 4.3,
#    'starVotes': 29,
#    'location': 'Winters, California',
#    'url': 'https://www.hikingproject.com/trail/7003896/stebbins-cold-canyon-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7058169_sqsmall_1555949033.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7058169_small_1555949033.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7058169_smallMed_1555949033.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7058169_medium_1555949033.jpg',
#    'length': 5.1,
#    'ascent': 1413,
#    'descent': -1409,
#    'high': 1539,
#    'low': 231,
#    'longitude': -122.097,
#    'latitude': 38.5119,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7018582,
#    'name': 'Hidden Falls Loop',
#    'type': 'Hike',
#    'summary': 'A loop with waterfalls that are tucked away and only visible once you reach viewing decks.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 9,
#    'location': 'North Auburn, California',
#    'url': 'https://www.hikingproject.com/trail/7018582/hidden-falls-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7018074_sqsmall_1554830282.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7018074_small_1554830282.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7018074_smallMed_1554830282.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7018074_medium_1554830282.jpg',
#    'length': 8.6,
#    'ascent': 811,
#    'descent': -812,
#    'high': 982,
#    'low': 431,
#    'longitude': -121.1644,
#    'latitude': 38.9589,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7003413,
#    'name': 'Cronan Ranch Loop',
#    'type': 'Hike',
#    'summary': 'An enjoyable hike with spectacular views of the Sierra Foothills and South Fork of the American River.',
#    'difficulty': 'greenBlue',
#    'stars': 4.2,
#    'starVotes': 18,
#    'location': 'Auburn Lake Trails, California',
#    'url': 'https://www.hikingproject.com/trail/7003413/cronan-ranch-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003212_sqsmall_1554233305.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003212_small_1554233305.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003212_smallMed_1554233305.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003212_medium_1554233305.jpg',
#    'length': 6.2,
#    'ascent': 771,
#    'descent': -760,
#    'high': 1231,
#    'low': 618,
#    'longitude': -120.9889,
#    'latitude': 38.826,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-11-24 05:19:55'},
#   {'id': 7070912,
#    'name': 'Black Hole of Calcutta Falls',
#    'type': 'Hike',
#    'summary': 'An easy, popular, scenic trail that is great for families or older folks.',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 5,
#    'location': 'Auburn, California',
#    'url': 'https://www.hikingproject.com/trail/7070912/black-hole-of-calcutta-falls',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7053911_sqsmall_1555704401.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7053911_small_1555704401.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7053911_smallMed_1555704401.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7053911_medium_1555704401.jpg',
#    'length': 2.1,
#    'ascent': 121,
#    'descent': -122,
#    'high': 701,
#    'low': 600,
#    'longitude': -121.04,
#    'latitude': 38.915,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-01-25 19:34:02'},
#   {'id': 7019896,
#    'name': 'Training Hill to Pig Farm to Robie Trail Loop',
#    'type': 'Hike',
#    'summary': 'After climbing half of Training Hill, this merciful loop returns via Pig Farm Trail.',
#    'difficulty': 'blueBlack',
#    'stars': 4,
#    'starVotes': 4,
#    'location': 'Auburn, California',
#    'url': 'https://www.hikingproject.com/trail/7019896/training-hill-to-pig-farm-to-robie-trail-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7020852_sqsmall_1554838934.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7020852_small_1554838934.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7020852_smallMed_1554838934.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7020852_medium_1554838934.jpg',
#    'length': 2.6,
#    'ascent': 752,
#    'descent': -751,
#    'high': 1358,
#    'low': 612,
#    'longitude': -121.0399,
#    'latitude': 38.9151,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7089210,
#    'name': 'Marshall Monument Loop',
#    'type': 'Hike',
#    'summary': 'A fun and educational loop.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Placerville, California',
#    'url': 'https://www.hikingproject.com/trail/7089210/marshall-monument-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7065305_sqsmall_1575665280.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7065305_small_1575665280.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7065305_smallMed_1575665280.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7065305_medium_1575665280.jpg',
#    'length': 3.5,
#    'ascent': 600,
#    'descent': -585,
#    'high': 1263,
#    'low': 746,
#    'longitude': -120.8928,
#    'latitude': 38.8016,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2019-12-29 13:43:37'},
#   {'id': 7089771,
#    'name': 'Foresthill Divide Loop',
#    'type': 'Hike',
#    'summary': 'A popular loop with hikers, runners and bikers.',
#    'difficulty': 'greenBlue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Auburn Lake Trails, California',
#    'url': 'https://www.hikingproject.com/trail/7089771/foresthill-divide-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7065886_sqsmall_1577811275.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7065886_small_1577811275.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7065886_smallMed_1577811275.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7065886_medium_1577811275.jpg',
#    'length': 11.2,
#    'ascent': 1087,
#    'descent': -1087,
#    'high': 1905,
#    'low': 1578,
#    'longitude': -120.9824,
#    'latitude': 38.9427,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7063430,
#    'name': 'Independence Flat Trail Loop',
#    'type': 'Hike',
#    'summary': 'Segment of the Mokelumne Coast to Crest Trail features river access and historic remains built during the gold rush.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Jackson, California',
#    'url': 'https://www.hikingproject.com/trail/7063430/independence-flat-trail-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7053950_sqsmall_1555704485.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7053950_small_1555704485.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7053950_smallMed_1555704485.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7053950_medium_1555704485.jpg',
#    'length': 4.3,
#    'ascent': 754,
#    'descent': -753,
#    'high': 1193,
#    'low': 593,
#    'longitude': -120.7497,
#    'latitude': 38.2973,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7090995,
#    'name': 'Zim Zim Falls',
#    'type': 'Hike',
#    'summary': 'A pleasant hike to a waterfall.',
#    'difficulty': 'greenBlue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Middletown, California',
#    'url': 'https://www.hikingproject.com/trail/7090995/zim-zim-falls',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7067334_sqsmall_1582519483.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7067334_small_1582519483.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7067334_smallMed_1582519483.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7067334_medium_1582519483.jpg',
#    'length': 7.8,
#    'ascent': 634,
#    'descent': -634,
#    'high': 1184,
#    'low': 717,
#    'longitude': -122.2836,
#    'latitude': 38.7519,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7037154,
#    'name': 'Fleming Meadow Trail #8',
#    'type': 'Hike',
#    'summary': 'Enjoy a beautiful loop in the trees in the Pollock Pines area of the Sierra.',
#    'difficulty': 'blue',
#    'stars': 4.1,
#    'starVotes': 8,
#    'location': 'Pollock Pines, California',
#    'url': 'https://www.hikingproject.com/trail/7037154/fleming-meadow-trail-8',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7037238_sqsmall_1555085549.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7037238_small_1555085549.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7037238_smallMed_1555085549.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7037238_medium_1555085549.jpg',
#    'length': 7.2,
#    'ascent': 1018,
#    'descent': -1024,
#    'high': 4107,
#    'low': 3589,
#    'longitude': -120.5452,
#    'latitude': 38.7088,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7041580,
#    'name': 'Miwok Trail / Hardy Canyon Trail Loop',
#    'type': 'Hike',
#    'summary': 'A great loop through Round Valley Regional Preserve.',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 3,
#    'location': 'Byron, California',
#    'url': 'https://www.hikingproject.com/trail/7041580/miwok-trail-hardy-canyon-trail-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039607_sqsmall_1555092282.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039607_small_1555092282.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039607_smallMed_1555092282.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039607_medium_1555092282.jpg',
#    'length': 4.8,
#    'ascent': 955,
#    'descent': -954,
#    'high': 1058,
#    'low': 228,
#    'longitude': -121.7503,
#    'latitude': 37.8684,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud - Cow abs horse poop is prominent.',
#    'conditionDate': '2019-12-26 18:45:33'},
#   {'id': 7023190,
#    'name': 'Stevens Trail',
#    'type': 'Hike',
#    'summary': 'This 7.7-mile out-and-back, moderately difficult trail will provide you with historical sights and spectacular views.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 27,
#    'location': 'Colfax, California',
#    'url': 'https://www.hikingproject.com/trail/7023190/stevens-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7040038_sqsmall_1555093017.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7040038_small_1555093017.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7040038_smallMed_1555093017.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7040038_medium_1555093017.jpg',
#    'length': 7.7,
#    'ascent': 1275,
#    'descent': -1276,
#    'high': 2384,
#    'low': 1253,
#    'longitude': -120.9472,
#    'latitude': 39.1056,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7000155,
#    'name': 'Vista Loop Trail',
#    'type': 'Hike',
#    'summary': 'Enjoyable jaunt affording views and a sense of the Sugarloaf Ridge Park area.',
#    'difficulty': 'greenBlue',
#    'stars': 3.7,
#    'starVotes': 3,
#    'location': 'Kenwood, California',
#    'url': 'https://www.hikingproject.com/trail/7000155/vista-loop-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002185_sqsmall_1554225423.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7002185_small_1554225423.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002185_smallMed_1554225423.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7002185_medium_1554225423.jpg',
#    'length': 3.6,
#    'ascent': 772,
#    'descent': -739,
#    'high': 1933,
#    'low': 1242,
#    'longitude': -122.5085,
#    'latitude': 38.4367,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7000146,
#    'name': 'Bald Mountain Loop',
#    'type': 'Hike',
#    'summary': 'Mediocre dirt roads and some singletrack trail lead to the finest views in Sonoma.',
#    'difficulty': 'blueBlack',
#    'stars': 4,
#    'starVotes': 9,
#    'location': 'Kenwood, California',
#    'url': 'https://www.hikingproject.com/trail/7000146/bald-mountain-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000266_sqsmall_1554159143.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7000266_small_1554159143.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000266_smallMed_1554159143.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7000266_medium_1554159143.jpg',
#    'length': 7,
#    'ascent': 1794,
#    'descent': -1798,
#    'high': 2726,
#    'low': 1206,
#    'longitude': -122.5141,
#    'latitude': 38.438,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7004254,
#    'name': 'Mount Hood via Goodspeed Trail',
#    'type': 'Hike',
#    'summary': 'From redwoods to chapparal to grassland to oak forest to HUGE views - this has it all!',
#    'difficulty': 'blue',
#    'stars': 4.3,
#    'starVotes': 7,
#    'location': 'Kenwood, California',
#    'url': 'https://www.hikingproject.com/trail/7004254/mount-hood-via-goodspeed-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003241_sqsmall_1554233368.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003241_small_1554233368.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003241_smallMed_1554233368.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003241_medium_1554233368.jpg',
#    'length': 6.1,
#    'ascent': 1982,
#    'descent': -1982,
#    'high': 2580,
#    'low': 752,
#    'longitude': -122.5317,
#    'latitude': 38.4425,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7041523,
#    'name': 'Mount Diablo Four Peaks Loop',
#    'type': 'Hike',
#    'summary': 'This long, challenging hike visits Mount Diablo and three other summits.',
#    'difficulty': 'blueBlack',
#    'stars': 4.6,
#    'starVotes': 11,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7041523/mount-diablo-four-peaks-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7011282_sqsmall_1554400324.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7011282_small_1554400324.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7011282_smallMed_1554400324.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7011282_medium_1554400324.jpg',
#    'length': 15.4,
#    'ascent': 4406,
#    'descent': -4404,
#    'high': 3808,
#    'low': 541,
#    'longitude': -121.927,
#    'latitude': 37.9221,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2020-02-08 12:08:02'},
#   {'id': 7042934,
#    'name': 'Mount Diablo Falls Loop',
#    'type': 'Hike',
#    'summary': 'This rugged and scenic hike explores the waterfalls around the headwaters of Donner Creek.',
#    'difficulty': 'blueBlack',
#    'stars': 4.7,
#    'starVotes': 15,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7042934/mount-diablo-falls-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7063558_sqsmall_1570208963.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7063558_small_1570208963.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7063558_smallMed_1570208963.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7063558_medium_1570208963.jpg',
#    'length': 5.4,
#    'ascent': 1107,
#    'descent': -1105,
#    'high': 1648,
#    'low': 542,
#    'longitude': -121.9271,
#    'latitude': 37.9221,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-02-15 14:28:53'},
#   {'id': 7040977,
#    'name': 'Mount Diablo Summit Loop - North',
#    'type': 'Hike',
#    'summary': "This strenuous loop hike tours Mount Diablo's ridges and canyons with a stop at the summit.",
#    'difficulty': 'blueBlack',
#    'stars': 4.1,
#    'starVotes': 10,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7040977/mount-diablo-summit-loop-north',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7011282_sqsmall_1554400324.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7011282_small_1554400324.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7011282_smallMed_1554400324.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7011282_medium_1554400324.jpg',
#    'length': 13.7,
#    'ascent': 3378,
#    'descent': -3369,
#    'high': 3774,
#    'low': 573,
#    'longitude': -121.9415,
#    'latitude': 37.9204,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry',
#    'conditionDate': '2020-01-11 10:48:42'},
#   {'id': 7040999,
#    'name': 'Eagle Peak Loop',
#    'type': 'Hike',
#    'summary': 'A moderate loop hike to a surprisingly dramatic summit near Mount Diablo.',
#    'difficulty': 'blueBlack',
#    'stars': 4.1,
#    'starVotes': 7,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7040999/eagle-peak-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7040756_sqsmall_1555094460.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7040756_small_1555094460.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7040756_smallMed_1555094460.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7040756_medium_1555094460.jpg',
#    'length': 6.5,
#    'ascent': 1983,
#    'descent': -1983,
#    'high': 2352,
#    'low': 631,
#    'longitude': -121.9415,
#    'latitude': 37.9204,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7029945,
#    'name': 'Annadel Park Channel Drive Loop',
#    'type': 'Hike',
#    'summary': 'Beautiful scenery, challenging terrain, and a great hill workout all in about an hour. What more could you ask for?!',
#    'difficulty': 'greenBlue',
#    'stars': 3.3,
#    'starVotes': 3,
#    'location': 'Santa Rosa, California',
#    'url': 'https://www.hikingproject.com/trail/7029945/annadel-park-channel-drive-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7036022_sqsmall_1555021390.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7036022_small_1555021390.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7036022_smallMed_1555021390.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7036022_medium_1555021390.jpg',
#    'length': 5,
#    'ascent': 671,
#    'descent': -667,
#    'high': 842,
#    'low': 333,
#    'longitude': -122.6384,
#    'latitude': 38.4566,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7023057,
#    'name': 'Ohlone-Crystyl Ranch Loop',
#    'type': 'Hike',
#    'summary': 'Enjoy sweeping views of the Walnut Creek and Concord areas on this hike located just off Ygnacio Rd.',
#    'difficulty': 'greenBlue',
#    'stars': 2.8,
#    'starVotes': 5,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7023057/ohlone-crystyl-ranch-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039404_sqsmall_1555091267.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039404_small_1555091267.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039404_smallMed_1555091267.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039404_medium_1555091267.jpg',
#    'length': 5.5,
#    'ascent': 734,
#    'descent': -747,
#    'high': 861,
#    'low': 372,
#    'longitude': -121.9925,
#    'latitude': 37.9467,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7004382,
#    'name': 'Sonoma Overlook Trail',
#    'type': 'Hike',
#    'summary': 'Quick and easy trip just above Sonoma with great views.',
#    'difficulty': 'greenBlue',
#    'stars': 4.3,
#    'starVotes': 3,
#    'location': 'Sonoma, California',
#    'url': 'https://www.hikingproject.com/trail/7004382/sonoma-overlook-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003515_sqsmall_1554234401.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003515_small_1554234401.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003515_smallMed_1554234401.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003515_medium_1554234401.jpg',
#    'length': 2.4,
#    'ascent': 372,
#    'descent': -372,
#    'high': 509,
#    'low': 137,
#    'longitude': -122.4571,
#    'latitude': 38.2997,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Mostly Dry, Some Mud',
#    'conditionDate': '2019-12-28 20:45:52'},
#   {'id': 7012637,
#    'name': 'Juniper to Summit Loop',
#    'type': 'Hike',
#    'summary': 'A combination of steep climbs and descents with stunning views of the San Francisco Bay Area.',
#    'difficulty': 'blue',
#    'stars': 3.8,
#    'starVotes': 13,
#    'location': 'Diablo, California',
#    'url': 'https://www.hikingproject.com/trail/7012637/juniper-to-summit-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7011282_sqsmall_1554400324.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7011282_small_1554400324.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7011282_smallMed_1554400324.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7011282_medium_1554400324.jpg',
#    'length': 6.6,
#    'ascent': 1737,
#    'descent': -1727,
#    'high': 3586,
#    'low': 2040,
#    'longitude': -121.9312,
#    'latitude': 37.8765,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': "Mostly Dry - A $10 day use fee, plus a $96 parking ticket if you don't get back to your car by sunset. Have a nice day!",
#    'conditionDate': '2019-12-29 05:32:21'},
#   {'id': 7017781,
#    'name': 'North Sonoma Mtn Trailhead to Sonoma Mtn Peak',
#    'type': 'Hike',
#    'summary': 'A gorgeous route including views of Bennett Valley on the way up to the peak of Sonoma Mountain.',
#    'difficulty': 'greenBlue',
#    'stars': 3.8,
#    'starVotes': 6,
#    'location': 'Eldridge, California',
#    'url': 'https://www.hikingproject.com/trail/7017781/north-sonoma-mtn-trailhead-to-sonoma-mtn-peak',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7017043_sqsmall_1554828713.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7017043_small_1554828713.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7017043_smallMed_1554828713.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7017043_medium_1554828713.jpg',
#    'length': 9.7,
#    'ascent': 1747,
#    'descent': -1748,
#    'high': 2363,
#    'low': 1066,
#    'longitude': -122.6044,
#    'latitude': 38.3635,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7033788,
#    'name': 'Tour de Table Mountain - Phantom Falls Loop',
#    'type': 'Hike',
#    'summary': 'Enjoy a tour of the best places in North Table Mountain Ecological Reserve.',
#    'difficulty': 'greenBlue',
#    'stars': 4.6,
#    'starVotes': 9,
#    'location': 'Oroville, California',
#    'url': 'https://www.hikingproject.com/trail/7033788/tour-de-table-mountain-phantom-falls-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7049585_sqsmall_1555688783.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7049585_small_1555688783.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7049585_smallMed_1555688783.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7049585_medium_1555688783.jpg',
#    'length': 6.9,
#    'ascent': 783,
#    'descent': -783,
#    'high': 1332,
#    'low': 920,
#    'longitude': -121.5418,
#    'latitude': 39.596,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7030209,
#    'name': 'Mt. Diablo Summit Loop - South',
#    'type': 'Hike',
#    'summary': 'A long loop hike through Mt. Diablo Foothills and to the summit of Mt. Diablo.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 8,
#    'location': 'Diablo, California',
#    'url': 'https://www.hikingproject.com/trail/7030209/mt-diablo-summit-loop-south',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7011282_sqsmall_1554400324.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7011282_small_1554400324.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7011282_smallMed_1554400324.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7011282_medium_1554400324.jpg',
#    'length': 16,
#    'ascent': 3679,
#    'descent': -3678,
#    'high': 3725,
#    'low': 616,
#    'longitude': -121.9788,
#    'latitude': 37.8627,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy - Muddy and slippery for first 4 miles but improves after that',
#    'conditionDate': '2020-01-30 14:05:48'},
#   {'id': 7054001,
#    'name': 'Stage Road Loop',
#    'type': 'Hike',
#    'summary': 'Pretty, moderate loop combining views of Wall Point, Mt. Diablo, and valley creek bed.',
#    'difficulty': 'greenBlue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Diablo, California',
#    'url': 'https://www.hikingproject.com/trail/7054001/stage-road-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039243_sqsmall_1555090796.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039243_small_1555090796.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039243_smallMed_1555090796.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039243_medium_1555090796.jpg',
#    'length': 4.1,
#    'ascent': 590,
#    'descent': -585,
#    'high': 878,
#    'low': 483,
#    'longitude': -121.9789,
#    'latitude': 37.8626,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2020-01-19 23:55:57'},
#   {'id': 7011686,
#    'name': 'Taylor Mountain',
#    'type': 'Hike',
#    'summary': 'A lovely short hike with great views and oak forest trails.',
#    'difficulty': 'blue',
#    'stars': 3.9,
#    'starVotes': 8,
#    'location': 'Roseland, California',
#    'url': 'https://www.hikingproject.com/trail/7011686/taylor-mountain',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7008625_sqsmall_1554325136.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7008625_small_1554325136.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7008625_smallMed_1554325136.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7008625_medium_1554325136.jpg',
#    'length': 5.1,
#    'ascent': 1155,
#    'descent': -1154,
#    'high': 1360,
#    'low': 206,
#    'longitude': -122.6973,
#    'latitude': 38.4046,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7041656,
#    'name': 'Craig Canyon-Thompson Canyon Loop',
#    'type': 'Hike',
#    'summary': 'This is an easy-to-follow loop around Cache Creek Wilderness, with a chance to see tule elk.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Arbuckle, California',
#    'url': 'https://www.hikingproject.com/trail/7041656/craig-canyon-thompson-canyon-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7041222_sqsmall_1555103808.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7041222_small_1555103808.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7041222_smallMed_1555103808.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7041222_medium_1555103808.jpg',
#    'length': 9.8,
#    'ascent': 1309,
#    'descent': -1309,
#    'high': 1674,
#    'low': 1012,
#    'longitude': -122.3544,
#    'latitude': 38.9985,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7022229,
#    'name': 'Briones Regional Park Loop',
#    'type': 'Hike',
#    'summary': 'A lovely hike in Briones Regional Park that is outstanding when the wildflowers are in bloom.',
#    'difficulty': 'blue',
#    'stars': 3.8,
#    'starVotes': 4,
#    'location': 'Pleasant Hill, California',
#    'url': 'https://www.hikingproject.com/trail/7022229/briones-regional-park-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7024026_sqsmall_1554846089.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7024026_small_1554846089.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7024026_smallMed_1554846089.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7024026_medium_1554846089.jpg',
#    'length': 9.6,
#    'ascent': 1503,
#    'descent': -1502,
#    'high': 1352,
#    'low': 679,
#    'longitude': -122.1353,
#    'latitude': 37.9541,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7042274,
#    'name': 'Ridgeline Loop',
#    'type': 'Hike',
#    'summary': 'A loop hike along the lake and on top of the ridge.',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 3,
#    'location': 'Livermore, California',
#    'url': 'https://www.hikingproject.com/trail/7042274/ridgeline-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7040304_sqsmall_1555093522.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7040304_small_1555093522.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7040304_smallMed_1555093522.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7040304_medium_1555093522.jpg',
#    'length': 4.8,
#    'ascent': 565,
#    'descent': -545,
#    'high': 1138,
#    'low': 713,
#    'longitude': -121.7035,
#    'latitude': 37.5866,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7056138,
#    'name': 'Eagle Peak Out and Back',
#    'type': 'Hike',
#    'summary': 'Excellent workout with great views of Mt. Diablo.',
#    'difficulty': 'black',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Alamo, California',
#    'url': 'https://www.hikingproject.com/trail/7056138/eagle-peak-out-and-back',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7052184_sqsmall_1555694830.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7052184_small_1555694830.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7052184_smallMed_1555694830.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7052184_medium_1555694830.jpg',
#    'length': 4.2,
#    'ascent': 1435,
#    'descent': -1434,
#    'high': 1791,
#    'low': 356,
#    'longitude': -122.0259,
#    'latitude': 37.834,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry',
#    'conditionDate': '2020-01-20 16:02:23'},
#   {'id': 7020222,
#    'name': 'Thunder Mountain',
#    'type': 'Hike',
#    'summary': 'A remarkably beautiful summit with surprisingly low relative effort - a true standout in the area.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 6,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7020222/thunder-mountain',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7041438_sqsmall_1555104233.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7041438_small_1555104233.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7041438_smallMed_1555104233.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7041438_medium_1555104233.jpg',
#    'length': 7.9,
#    'ascent': 1858,
#    'descent': -1858,
#    'high': 9388,
#    'low': 7929,
#    'longitude': -120.1075,
#    'latitude': 38.7056,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7084341,
#    'name': '10k Loop at Briones',
#    'type': 'Hike',
#    'summary': 'Great loop with moderate elevation, spectacular views, and beautiful nature.',
#    'difficulty': 'blueBlack',
#    'stars': 4,
#    'starVotes': 3,
#    'location': 'Orinda, California',
#    'url': 'https://www.hikingproject.com/trail/7084341/10k-loop-at-briones',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7023196_sqsmall_1554844656.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7023196_small_1554844656.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7023196_smallMed_1554844656.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7023196_medium_1554844656.jpg',
#    'length': 6.9,
#    'ascent': 773,
#    'descent': -773,
#    'high': 1431,
#    'low': 718,
#    'longitude': -122.1565,
#    'latitude': 37.9268,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy',
#    'conditionDate': '2019-12-21 14:11:33'},
#   {'id': 7090570,
#    'name': 'Cache Creek Ford',
#    'type': 'Hike',
#    'summary': 'A long trek along ridgelines, and rolling hills within the Cache Creek Natural Area, with two creek crossings.',
#    'difficulty': 'black',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Clearlake, California',
#    'url': 'https://www.hikingproject.com/trail/7090570/cache-creek-ford',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7066726_sqsmall_1580443597.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7066726_small_1580443597.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7066726_smallMed_1580443597.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7066726_medium_1580443597.jpg',
#    'length': 13.1,
#    'ascent': 1543,
#    'descent': -2288,
#    'high': 2208,
#    'low': 903,
#    'longitude': -122.4158,
#    'latitude': 39.0086,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7033835,
#    'name': 'Feather Falls Loop',
#    'type': 'Hike',
#    'summary': 'Enjoy the beautiful Plumas National Forest on your way to a phenomenal waterfall.',
#    'difficulty': 'blue',
#    'stars': 4.1,
#    'starVotes': 8,
#    'location': 'Berry Creek, California',
#    'url': 'https://www.hikingproject.com/trail/7033835/feather-falls-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7034434_sqsmall_1555000248.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7034434_small_1555000248.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7034434_smallMed_1555000248.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7034434_medium_1555000248.jpg',
#    'length': 8,
#    'ascent': 1870,
#    'descent': -1868,
#    'high': 2483,
#    'low': 1518,
#    'longitude': -121.2666,
#    'latitude': 39.6144,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7019355,
#    'name': 'Dangberg Loop',
#    'type': 'Hike',
#    'summary': 'A mostly gradual route that traverse up the roads and trails at Kirkwood before descending back to the base.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7019355/dangberg-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7020145_sqsmall_1554837883.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7020145_small_1554837883.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7020145_smallMed_1554837883.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7020145_medium_1554837883.jpg',
#    'length': 4.4,
#    'ascent': 650,
#    'descent': -646,
#    'high': 8287,
#    'low': 7784,
#    'longitude': -120.0666,
#    'latitude': 38.684,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7084098,
#    'name': 'Osborne Ridge Loop',
#    'type': 'Hike',
#    'summary': 'Panoramic ridge views and lush green forests.',
#    'difficulty': 'blueBlack',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7084098/osborne-ridge-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7060340_sqsmall_1562691992.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7060340_small_1562691992.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7060340_smallMed_1562691992.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7060340_medium_1562691992.jpg',
#    'length': 3.9,
#    'ascent': 688,
#    'descent': -687,
#    'high': 7783,
#    'low': 7178,
#    'longitude': -120.0175,
#    'latitude': 38.4817,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015165,
#    'name': 'Las Trampas North Loop',
#    'type': 'Hike',
#    'summary': 'Plenty of climbing means you get great views from the peak and all along the Ridge Trail.',
#    'difficulty': 'blueBlack',
#    'stars': 4,
#    'starVotes': 8,
#    'location': 'Danville, California',
#    'url': 'https://www.hikingproject.com/trail/7015165/las-trampas-north-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7052184_sqsmall_1555694830.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7052184_small_1555694830.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7052184_smallMed_1555694830.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7052184_medium_1555694830.jpg',
#    'length': 9.6,
#    'ascent': 2273,
#    'descent': -2300,
#    'high': 1796,
#    'low': 646,
#    'longitude': -122.0498,
#    'latitude': 37.8168,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7010463,
#    'name': 'Elderberry - Rocky View - Cuestas Loop',
#    'type': 'Hike',
#    'summary': 'Great loop with views of the bay and Mt. Diablo',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 7,
#    'location': 'Danville, California',
#    'url': 'https://www.hikingproject.com/trail/7010463/elderberry-rocky-view-cuestas-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038405_sqsmall_1555088279.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7038405_small_1555088279.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038405_smallMed_1555088279.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7038405_medium_1555088279.jpg',
#    'length': 8.1,
#    'ascent': 1397,
#    'descent': -1396,
#    'high': 1954,
#    'low': 993,
#    'longitude': -122.0439,
#    'latitude': 37.8121,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7088710,
#    'name': 'Rim Trail',
#    'type': 'Hike',
#    'summary': 'A pleasant hike through the Lamorinda hills with great views.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Lafayette, California',
#    'url': 'https://www.hikingproject.com/trail/7088710/rim-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7064941_sqsmall_1574640280.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7064941_small_1574640280.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7064941_smallMed_1574640280.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7064941_medium_1574640280.jpg',
#    'length': 5.2,
#    'ascent': 903,
#    'descent': -901,
#    'high': 1023,
#    'low': 469,
#    'longitude': -122.1385,
#    'latitude': 37.8843,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry: Footing on downhill sections can be a bit tricky at times.',
#    'conditionDate': '2019-11-24 17:21:09'},
#   {'id': 7085300,
#    'name': 'Rockbound Trail to Leland Lakes',
#    'type': 'Hike',
#    'summary': 'Backpack through beautiful pine forests over rocky passes and camp by rushing rivers and quiet lakes.',
#    'difficulty': 'black',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7085300/rockbound-trail-to-leland-lakes',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7061895_sqsmall_1565819169.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7061895_small_1565819169.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7061895_smallMed_1565819169.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7061895_medium_1565819169.jpg',
#    'length': 10.4,
#    'ascent': 2719,
#    'descent': -1528,
#    'high': 8540,
#    'low': 6967,
#    'longitude': -120.2391,
#    'latitude': 38.8482,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7091000,
#    'name': 'Briones Reservoir Loop Trail',
#    'type': 'Hike',
#    'summary': 'A great long hike around Briones Reservoir.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Orinda, California',
#    'url': 'https://www.hikingproject.com/trail/7091000/briones-reservoir-loop-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039477_sqsmall_1555091626.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039477_small_1555091626.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039477_smallMed_1555091626.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039477_medium_1555091626.jpg',
#    'length': 13.4,
#    'ascent': 1081,
#    'descent': -1087,
#    'high': 993,
#    'low': 586,
#    'longitude': -122.2024,
#    'latitude': 37.9132,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7037745,
#    'name': 'Wrights Lake to Grouse Lake',
#    'type': 'Hike',
#    'summary': 'A nice climb through forests and granite slabs to the secluded Grouse Lake.',
#    'difficulty': 'blueBlack',
#    'stars': 3.8,
#    'starVotes': 4,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7037745/wrights-lake-to-grouse-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7037572_sqsmall_1555086309.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7037572_small_1555086309.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7037572_smallMed_1555086309.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7037572_medium_1555086309.jpg',
#    'length': 4.5,
#    'ascent': 1212,
#    'descent': -1212,
#    'high': 8152,
#    'low': 6956,
#    'longitude': -120.2256,
#    'latitude': 38.8496,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7018678,
#    'name': 'Armstrong Redwoods Tour',
#    'type': 'Hike',
#    'summary': 'A beautiful, easy hike through a "young" old-growth redwood forest.',
#    'difficulty': 'green',
#    'stars': 4.2,
#    'starVotes': 6,
#    'location': 'Guerneville, California',
#    'url': 'https://www.hikingproject.com/trail/7018678/armstrong-redwoods-tour',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7018315_sqsmall_1554830686.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7018315_small_1554830686.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7018315_smallMed_1554830686.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7018315_medium_1554830686.jpg',
#    'length': 2.1,
#    'ascent': 200,
#    'descent': -199,
#    'high': 359,
#    'low': 252,
#    'longitude': -123.003,
#    'latitude': 38.5324,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7024572,
#    'name': 'Round Top Loop',
#    'type': 'Hike',
#    'summary': 'A moderate scramble up a Sierra Nevada peak.',
#    'difficulty': 'black',
#    'stars': 4.9,
#    'starVotes': 7,
#    'location': 'South Lake Tahoe, California',
#    'url': 'https://www.hikingproject.com/trail/7024572/round-top-loop',
# ...
#    'latitude': 38.2689,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7054712,
#    'name': 'Marie Creek Trail',
#    'type': 'Trail',
#    'summary': 'A great singletrack.',
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Green Valley, California',
#    'url': 'https://www.hikingproject.com/trail/7054712/marie-creek-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.8,
#    'ascent': 0,
#    'descent': -354,
#    'high': 804,
#    'low': 450,
#    'longitude': -122.2309,
#    'latitude': 38.2613,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7040721,
#    'name': 'Lower Skyline Trail',
#    'type': 'Trail',
#    'summary': 'A mostly smooth trail under the shade of oaks with some rocks and steep ruts to keep it interesting.',
#    'difficulty': 'blueBlack',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Napa, California',
#    'url': 'https://www.hikingproject.com/trail/7040721/lower-skyline-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.9,
#    'ascent': 0,
#    'descent': -559,
#    'high': 790,
#    'low': 231,
#    'longitude': -122.2455,
#    'latitude': 38.2717,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7040720,
#    'name': 'Buckeye Trail',
#    'type': 'Trail',
#    'summary': 'Rocks, roots, steps, and smooth sections, this trail is a grunt to climb and fun coming down.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 4,
#    'location': 'Napa, California',
#    'url': 'https://www.hikingproject.com/trail/7040720/buckeye-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 2.3,
#    'ascent': 696,
#    'descent': -42,
#    'high': 882,
#    'low': 222,
#    'longitude': -122.2518,
#    'latitude': 38.2749,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7030887,
#    'name': 'Upper Oat Hill Mine Trail',
#    'type': 'Trail',
#    'summary': 'This trail leads aross striking volcanic formations as you traverse through sweeping vistas of Napa Valley.',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 2,
#    'location': 'Calistoga, California',
#    'url': 'https://www.hikingproject.com/trail/7030887/upper-oat-hill-mine-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038814_sqsmall_1555089710.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7038814_small_1555089710.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038814_smallMed_1555089710.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7038814_medium_1555089710.jpg',
#    'length': 3.8,
#    'ascent': 501,
#    'descent': -414,
#    'high': 2511,
#    'low': 2202,
#    'longitude': -122.5255,
#    'latitude': 38.6477,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7087713,
#    'name': 'Saddle Trail',
#    'type': 'Trail',
#    'summary': 'The Saddle Trail is a short trail in the Black Diamond Mines Regional Reserve.',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7087713/saddle-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.5,
#    'ascent': 225,
#    'descent': -35,
#    'high': 1127,
#    'low': 902,
#    'longitude': -121.861,
#    'latitude': 37.9608,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015054,
#    'name': 'Carbondale Trail',
#    'type': 'Trail',
#    'summary': 'A north to south ranch road connecting Stewartville Trail with River View Trail.',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7015054/carbondale-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.2,
#    'ascent': 131,
#    'descent': -272,
#    'high': 1184,
#    'low': 911,
#    'longitude': -121.8541,
#    'latitude': 37.9527,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7023821,
#    'name': 'Cemetery Loop',
#    'type': 'Trail',
#    'summary': 'A short loop trail past the Kneebone Family Cemetery.',
#    'difficulty': 'green',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Lake Wildwood, California',
#    'url': 'https://www.hikingproject.com/trail/7023821/cemetery-loop',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.5,
#    'ascent': 15,
#    'descent': -22,
#    'high': 566,
#    'low': 544,
#    'longitude': -121.1952,
#    'latitude': 39.2917,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015083,
#    'name': 'River View Trailhead Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7015083/river-view-trailhead-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 18,
#    'descent': 0,
#    'high': 756,
#    'low': 738,
#    'longitude': -121.8633,
#    'latitude': 37.9582,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7038651,
#    'name': 'Blue Ridge Trail',
#    'type': 'Trail',
#    'summary': 'An epic ridge trail.',
#    'difficulty': 'black',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Hidden Valley Lake, California',
#    'url': 'https://www.hikingproject.com/trail/7038651/blue-ridge-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 8.4,
#    'ascent': 880,
#    'descent': -2978,
#    'high': 3012,
#    'low': 589,
#    'longitude': -122.2896,
#    'latitude': 38.842,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7043255,
#    'name': 'Miwok Trail',
#    'type': 'Trail',
#    'summary': 'Needs Summary',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 2,
#    'location': 'Byron, California',
#    'url': 'https://www.hikingproject.com/trail/7043255/miwok-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7041397_sqsmall_1555104145.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7041397_small_1555104145.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7041397_smallMed_1555104145.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7041397_medium_1555104145.jpg',
#    'length': 5.9,
#    'ascent': 1859,
#    'descent': -127,
#    'high': 1981,
#    'low': 247,
#    'longitude': -121.7502,
#    'latitude': 37.8684,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud - Cow abs horse poop is prominent.',
#    'conditionDate': '2019-12-26 18:45:38'},
#   {'id': 7015050,
#    'name': 'River View Trail',
#    'type': 'Trail',
#    'summary': 'A steady ridge-climb on a wide, smooth fire road.',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7015050/river-view-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.6,
#    'ascent': 235,
#    'descent': -207,
#    'high': 1034,
#    'low': 798,
#    'longitude': -121.8626,
#    'latitude': 37.9567,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015055,
#    'name': 'Stewartville Trail',
#    'type': 'Trail',
#    'summary': "An old mining and ranch road that's mostly flat and easy with one really steep ridge.",
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 4,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7015055/stewartville-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 4.9,
#    'ascent': 451,
#    'descent': -955,
#    'high': 1130,
#    'low': 265,
#    'longitude': -121.8638,
#    'latitude': 37.9576,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7043254,
#    'name': 'Hardy Canyon Trail',
#    'type': 'Trail',
#    'summary': 'Needs Summary',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Byron, California',
#    'url': 'https://www.hikingproject.com/trail/7043254/hardy-canyon-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039607_sqsmall_1555092282.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039607_small_1555092282.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039607_smallMed_1555092282.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039607_medium_1555092282.jpg',
#    'length': 3.1,
#    'ascent': 857,
#    'descent': -715,
#    'high': 1059,
#    'low': 227,
#    'longitude': -121.7514,
#    'latitude': 37.8676,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud - Cow abs horse poop is prominent.',
#    'conditionDate': '2019-12-26 18:45:38'},
#   {'id': 7015044,
#    'name': 'Nortonville Trail',
#    'type': 'Trail',
#    'summary': 'An old road connecting the Nortonville and Somersville town sites.',
#    'difficulty': 'blueBlack',
#    'stars': 3,
#    'starVotes': 3,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7015044/nortonville-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.2,
#    'ascent': 333,
#    'descent': -318,
#    'high': 1091,
#    'low': 758,
#    'longitude': -121.8644,
#    'latitude': 37.9567,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7023719,
#    'name': 'Buttermilk Bend Trail Lower Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Lake Wildwood, California',
#    'url': 'https://www.hikingproject.com/trail/7023719/buttermilk-bend-trail-lower-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 72,
#    'descent': 0,
#    'high': 644,
#    'low': 572,
#    'longitude': -121.1924,
#    'latitude': 39.2932,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7023717,
#    'name': 'Buttermilk Bend Trail',
#    'type': 'Trail',
#    'summary': 'An easy riverside trail with bold wildflower displays in the spring',
#    'difficulty': 'green',
#    'stars': 3.5,
#    'starVotes': 4,
#    'location': 'Lake Wildwood, California',
#    'url': 'https://www.hikingproject.com/trail/7023717/buttermilk-bend-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7046346_sqsmall_1555534542.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7046346_small_1555534542.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7046346_smallMed_1555534542.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7046346_medium_1555534542.jpg',
#    'length': 1.3,
#    'ascent': 140,
#    'descent': -69,
#    'high': 697,
#    'low': 594,
#    'longitude': -121.1923,
#    'latitude': 39.2939,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7051703,
#    'name': 'Stevens Trail',
#    'type': 'Trail',
#    'summary': 'Needs Summary',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 2,
#    'location': 'Colfax, California',
#    'url': 'https://www.hikingproject.com/trail/7051703/stevens-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7040038_sqsmall_1555093017.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7040038_small_1555093017.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7040038_smallMed_1555093017.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7040038_medium_1555093017.jpg',
#    'length': 3.8,
#    'ascent': 127,
#    'descent': -1271,
#    'high': 2371,
#    'low': 1227,
#    'longitude': -120.9471,
#    'latitude': 39.1057,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7086303,
#    'name': 'Lower Chaparral Trail',
#    'type': 'Trail',
#    'summary': 'Beautiful, difficult, and technical. Be cautious on the descent.',
#    'difficulty': 'black',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7086303/lower-chaparral-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.3,
#    'ascent': 0,
#    'descent': -270,
#    'high': 1042,
#    'low': 772,
#    'longitude': -121.865,
#    'latitude': 37.9523,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7000151,
#    'name': 'Gray Pine Trail',
#    'type': 'Trail',
#    'summary': 'Spectacular scenery along a high ridgeline.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Kenwood, California',
#    'url': 'https://www.hikingproject.com/trail/7000151/gray-pine-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000266_sqsmall_1554159143.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7000266_small_1554159143.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000266_smallMed_1554159143.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7000266_medium_1554159143.jpg',
#    'length': 2.6,
#    'ascent': 9,
#    'descent': -1399,
#    'high': 2711,
#    'low': 1321,
#    'longitude': -122.5092,
#    'latitude': 38.4574,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015046,
#    'name': 'Ridge Trail',
#    'type': 'Trail',
#    'summary': 'A roller coaster, ridge-top fire road with great views and drawn-out descents.',
#    'difficulty': 'blueBlack',
#    'stars': 3.7,
#    'starVotes': 3,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7015046/ridge-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 2.9,
#    'ascent': 213,
#    'descent': -802,
#    'high': 1253,
#    'low': 580,
#    'longitude': -121.8647,
#    'latitude': 37.9509,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7086306,
#    'name': 'Chaparral Loop Trail',
#    'type': 'Trail',
#    'summary': 'This is a beautiful, albeit difficult trail alternative to the Lower Chaparral Trail.',
#    'difficulty': 'black',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Clayton, California',
#    'url': 'https://www.hikingproject.com/trail/7086306/chaparral-loop-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.9,
#    'ascent': 211,
#    'descent': -381,
#    'high': 1169,
#    'low': 806,
#    'longitude': -121.8687,
#    'latitude': 37.9535,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7023720,
#    'name': 'Buttermilk Bend Trail Upper Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Lake Wildwood, California',
#    'url': 'https://www.hikingproject.com/trail/7023720/buttermilk-bend-trail-upper-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.3,
#    'ascent': 0,
#    'descent': -142,
#    'high': 847,
#    'low': 705,
#    'longitude': -121.1851,
#    'latitude': 39.2959,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'}],
#  'success': 1}

# %%
len(data["trails"])
# Out:
# 500

# %% [markdown]
# >Ah, much better.

# %% [markdown]
# <h2> Step 3: Utilize Pandas to better view and manipulate data </h2>

# %%
# Storing returned api data as a Pandas dataframe.

trails_df = pd.DataFrame(data["trails"])

# %%
trails_df
# Out:
#           id                                   name       type  \
# 0    7021990                  Seasonal Wetland Loop       Hike
# 1    7089186                            Nature Loop       Hike
# 2    7023706                   Cosumnes Nature Loop       Hike
# 3    7016942                       Lake Natoma Loop       Hike
# 4    7027546           Traylor Ranch Bird Sanctuary       Hike
# ..       ...                                    ...        ...
# 495  7086303                  Lower Chaparral Trail      Trail
# 496  7000151                        Gray Pine Trail      Trail
# 497  7015046                            Ridge Trail      Trail
# 498  7086306                   Chaparral Loop Trail      Trail
# 499  7023720  Buttermilk Bend Trail Upper Connector  Connector
#
#                                                summary difficulty  stars  \
# 0    A scenic loop around one of the wetland areas ...      green    3.5
# 1                A common loop that explores the park.  greenBlue    5.0
# 2    A nature-watcher's delight that follows trails...      green    4.0
# 3    Hike around Lake Natoma on bike paths with an ...  greenBlue    4.2
# 4    There are lots of birds to see and lots of loo...      green    2.0
# ..                                                 ...        ...    ...
# 495  Beautiful, difficult, and technical. Be cautio...      black    3.0
# 496        Spectacular scenery along a high ridgeline.       blue    4.0
# 497  A roller coaster, ridge-top fire road with gre...  blueBlack    3.7
# 498  This is a beautiful, albeit difficult trail al...      black    3.0
# 499                                                         green    0.0
#
#      starVotes                   location  \
# 0            2          Davis, California
# 1            1     Carmichael, California
# 2            9       Thornton, California
# 3            9         Folsom, California
# 4            3         Loomis, California
# ..         ...                        ...
# 495          1        Clayton, California
# 496          1        Kenwood, California
# 497          3        Clayton, California
# 498          1        Clayton, California
# 499          0  Lake Wildwood, California
#
#                                                    url  \
# 0    https://www.hikingproject.com/trail/7021990/se...
# 1    https://www.hikingproject.com/trail/7089186/na...
# 2    https://www.hikingproject.com/trail/7023706/co...
# 3    https://www.hikingproject.com/trail/7016942/la...
# 4    https://www.hikingproject.com/trail/7027546/tr...
# ..                                                 ...
# 495  https://www.hikingproject.com/trail/7086303/lo...
# 496  https://www.hikingproject.com/trail/7000151/gr...
# 497  https://www.hikingproject.com/trail/7015046/ri...
# 498  https://www.hikingproject.com/trail/7086306/ch...
# 499  https://www.hikingproject.com/trail/7023720/bu...
#
#                                             imgSqSmall  ... length ascent  \
# 0    https://cdn-files.apstatic.com/hike/7063351_sq...  ...    3.1     10
# 1    https://cdn-files.apstatic.com/hike/7065291_sq...  ...    1.6     21
# 2    https://cdn-files.apstatic.com/hike/7057450_sq...  ...    4.0     88
# 3    https://cdn-files.apstatic.com/hike/7016940_sq...  ...   12.0    293
# 4    https://cdn-files.apstatic.com/hike/7044187_sq...  ...    3.2     65
# ..                                                 ...  ...    ...    ...
# 495                                                     ...    0.3      0
# 496  https://cdn-files.apstatic.com/hike/7000266_sq...  ...    2.6      9
# 497                                                     ...    2.9    213
# 498                                                     ...    0.9    211
# 499                                                     ...    0.3      0
#
#     descent  high   low  longitude  latitude  conditionStatus  \
# 0       -12    17    11  -121.6261   38.5505          Unknown
# 1       -20    77    69  -121.3127   38.6168          Unknown
# 2       -84    51     9  -121.4403   38.2657          Unknown
# 3      -294   194   110  -121.1804   38.6766          Unknown
# 4       -65   430   396  -121.2058   38.8485          Unknown
# ..      ...   ...   ...        ...       ...              ...
# 495    -270  1042   772  -121.8650   37.9523          Unknown
# 496   -1399  2711  1321  -122.5092   38.4574          Unknown
# 497    -802  1253   580  -121.8647   37.9509          Unknown
# 498    -381  1169   806  -121.8687   37.9535          Unknown
# 499    -142   847   705  -121.1851   39.2959          Unknown
#
#      conditionDetails        conditionDate
# 0                None  1970-01-01 00:00:00
# 1                None  1970-01-01 00:00:00
# 2                None  1970-01-01 00:00:00
# 3                None  1970-01-01 00:00:00
# 4                None  1970-01-01 00:00:00
# ..                ...                  ...
# 495              None  1970-01-01 00:00:00
# 496              None  1970-01-01 00:00:00
# 497              None  1970-01-01 00:00:00
# 498              None  1970-01-01 00:00:00
# 499              None  1970-01-01 00:00:00
#
# [500 rows x 23 columns]

# %% [markdown]
# >Uh oh. Check out the 'difficulty' category. Looks like it is color coded.
# >Let's replace values to be more intuitive for our analysis.
# >
# >Need to convert color names to difficulty equivalents based on Hiking Trails API documentation
# >
# >(green = easy ; blue = intermediate ; black = difficult ; and any combination thereof)
# >
# >Note: We also ran initial script and used groupby('difficulty') to identify missed categories.
# >Script shown below has beeen modified accordingly.

# %%
trails_df['difficulty'] = trails_df['difficulty'].replace('green','Easy')
trails_df['difficulty'] = trails_df['difficulty'].replace('greenBlue','Easy/Intermediate')
trails_df['difficulty'] = trails_df['difficulty'].replace('blue','Intermediate')
trails_df['difficulty'] = trails_df['difficulty'].replace('blueBlack','Intermediate/Difficult')
trails_df['difficulty'] = trails_df['difficulty'].replace('black','Difficult')
trails_df['difficulty'] = trails_df['difficulty'].replace('dblack','Extremely Difficult')
trails_df
# Out:
#           id                                   name       type  \
# 0    7021990                  Seasonal Wetland Loop       Hike
# 1    7089186                            Nature Loop       Hike
# 2    7023706                   Cosumnes Nature Loop       Hike
# 3    7016942                       Lake Natoma Loop       Hike
# 4    7027546           Traylor Ranch Bird Sanctuary       Hike
# ..       ...                                    ...        ...
# 495  7086303                  Lower Chaparral Trail      Trail
# 496  7000151                        Gray Pine Trail      Trail
# 497  7015046                            Ridge Trail      Trail
# 498  7086306                   Chaparral Loop Trail      Trail
# 499  7023720  Buttermilk Bend Trail Upper Connector  Connector
#
#                                                summary  \
# 0    A scenic loop around one of the wetland areas ...
# 1                A common loop that explores the park.
# 2    A nature-watcher's delight that follows trails...
# 3    Hike around Lake Natoma on bike paths with an ...
# 4    There are lots of birds to see and lots of loo...
# ..                                                 ...
# 495  Beautiful, difficult, and technical. Be cautio...
# 496        Spectacular scenery along a high ridgeline.
# 497  A roller coaster, ridge-top fire road with gre...
# 498  This is a beautiful, albeit difficult trail al...
# 499
#
#                  difficulty  stars  starVotes                   location  \
# 0                      Easy    3.5          2          Davis, California
# 1         Easy/Intermediate    5.0          1     Carmichael, California
# 2                      Easy    4.0          9       Thornton, California
# 3         Easy/Intermediate    4.2          9         Folsom, California
# 4                      Easy    2.0          3         Loomis, California
# ..                      ...    ...        ...                        ...
# 495               Difficult    3.0          1        Clayton, California
# 496            Intermediate    4.0          1        Kenwood, California
# 497  Intermediate/Difficult    3.7          3        Clayton, California
# 498               Difficult    3.0          1        Clayton, California
# 499                    Easy    0.0          0  Lake Wildwood, California
#
#                                                    url  \
# 0    https://www.hikingproject.com/trail/7021990/se...
# 1    https://www.hikingproject.com/trail/7089186/na...
# 2    https://www.hikingproject.com/trail/7023706/co...
# 3    https://www.hikingproject.com/trail/7016942/la...
# 4    https://www.hikingproject.com/trail/7027546/tr...
# ..                                                 ...
# 495  https://www.hikingproject.com/trail/7086303/lo...
# 496  https://www.hikingproject.com/trail/7000151/gr...
# 497  https://www.hikingproject.com/trail/7015046/ri...
# 498  https://www.hikingproject.com/trail/7086306/ch...
# 499  https://www.hikingproject.com/trail/7023720/bu...
#
#                                             imgSqSmall  ... length ascent  \
# 0    https://cdn-files.apstatic.com/hike/7063351_sq...  ...    3.1     10
# 1    https://cdn-files.apstatic.com/hike/7065291_sq...  ...    1.6     21
# 2    https://cdn-files.apstatic.com/hike/7057450_sq...  ...    4.0     88
# 3    https://cdn-files.apstatic.com/hike/7016940_sq...  ...   12.0    293
# 4    https://cdn-files.apstatic.com/hike/7044187_sq...  ...    3.2     65
# ..                                                 ...  ...    ...    ...
# 495                                                     ...    0.3      0
# 496  https://cdn-files.apstatic.com/hike/7000266_sq...  ...    2.6      9
# 497                                                     ...    2.9    213
# 498                                                     ...    0.9    211
# 499                                                     ...    0.3      0
#
#     descent  high   low  longitude  latitude  conditionStatus  \
# 0       -12    17    11  -121.6261   38.5505          Unknown
# 1       -20    77    69  -121.3127   38.6168          Unknown
# 2       -84    51     9  -121.4403   38.2657          Unknown
# 3      -294   194   110  -121.1804   38.6766          Unknown
# 4       -65   430   396  -121.2058   38.8485          Unknown
# ..      ...   ...   ...        ...       ...              ...
# 495    -270  1042   772  -121.8650   37.9523          Unknown
# 496   -1399  2711  1321  -122.5092   38.4574          Unknown
# 497    -802  1253   580  -121.8647   37.9509          Unknown
# 498    -381  1169   806  -121.8687   37.9535          Unknown
# 499    -142   847   705  -121.1851   39.2959          Unknown
#
#      conditionDetails        conditionDate
# 0                None  1970-01-01 00:00:00
# 1                None  1970-01-01 00:00:00
# 2                None  1970-01-01 00:00:00
# 3                None  1970-01-01 00:00:00
# 4                None  1970-01-01 00:00:00
# ..                ...                  ...
# 495              None  1970-01-01 00:00:00
# 496              None  1970-01-01 00:00:00
# 497              None  1970-01-01 00:00:00
# 498              None  1970-01-01 00:00:00
# 499              None  1970-01-01 00:00:00
#
# [500 rows x 23 columns]

# %%
trails_df.columns
# Out:
# Index(['id', 'name', 'type', 'summary', 'difficulty', 'stars', 'starVotes',
#        'location', 'url', 'imgSqSmall', 'imgSmall', 'imgSmallMed', 'imgMedium',
#        'length', 'ascent', 'descent', 'high', 'low', 'longitude', 'latitude',
#        'conditionStatus', 'conditionDetails', 'conditionDate'],
#       dtype='object')

# %% [markdown]
# > We don't need image files or urls, so let's drop from analysis.

# %%
trails_dropped = pd.DataFrame(trails_df[['id', 'name', 'type', 'summary', 'difficulty', 'stars', 'starVotes',
       'location', 'length', 'ascent', 'descent', 'high', 'low', 'longitude', 'latitude',
       'conditionStatus', 'conditionDetails', 'conditionDate']])

# %%
trails_dropped
# Out:
#           id                                   name       type  \
# 0    7021990                  Seasonal Wetland Loop       Hike
# 1    7089186                            Nature Loop       Hike
# 2    7023706                   Cosumnes Nature Loop       Hike
# 3    7016942                       Lake Natoma Loop       Hike
# 4    7027546           Traylor Ranch Bird Sanctuary       Hike
# ..       ...                                    ...        ...
# 495  7086303                  Lower Chaparral Trail      Trail
# 496  7000151                        Gray Pine Trail      Trail
# 497  7015046                            Ridge Trail      Trail
# 498  7086306                   Chaparral Loop Trail      Trail
# 499  7023720  Buttermilk Bend Trail Upper Connector  Connector
#
#                                                summary  \
# 0    A scenic loop around one of the wetland areas ...
# 1                A common loop that explores the park.
# 2    A nature-watcher's delight that follows trails...
# 3    Hike around Lake Natoma on bike paths with an ...
# 4    There are lots of birds to see and lots of loo...
# ..                                                 ...
# 495  Beautiful, difficult, and technical. Be cautio...
# 496        Spectacular scenery along a high ridgeline.
# 497  A roller coaster, ridge-top fire road with gre...
# 498  This is a beautiful, albeit difficult trail al...
# 499
#
#                  difficulty  stars  starVotes                   location  \
# 0                      Easy    3.5          2          Davis, California
# 1         Easy/Intermediate    5.0          1     Carmichael, California
# 2                      Easy    4.0          9       Thornton, California
# 3         Easy/Intermediate    4.2          9         Folsom, California
# 4                      Easy    2.0          3         Loomis, California
# ..                      ...    ...        ...                        ...
# 495               Difficult    3.0          1        Clayton, California
# 496            Intermediate    4.0          1        Kenwood, California
# 497  Intermediate/Difficult    3.7          3        Clayton, California
# 498               Difficult    3.0          1        Clayton, California
# 499                    Easy    0.0          0  Lake Wildwood, California
#
#      length  ascent  descent  high   low  longitude  latitude conditionStatus  \
# 0       3.1      10      -12    17    11  -121.6261   38.5505         Unknown
# 1       1.6      21      -20    77    69  -121.3127   38.6168         Unknown
# 2       4.0      88      -84    51     9  -121.4403   38.2657         Unknown
# 3      12.0     293     -294   194   110  -121.1804   38.6766         Unknown
# 4       3.2      65      -65   430   396  -121.2058   38.8485         Unknown
# ..      ...     ...      ...   ...   ...        ...       ...             ...
# 495     0.3       0     -270  1042   772  -121.8650   37.9523         Unknown
# 496     2.6       9    -1399  2711  1321  -122.5092   38.4574         Unknown
# 497     2.9     213     -802  1253   580  -121.8647   37.9509         Unknown
# 498     0.9     211     -381  1169   806  -121.8687   37.9535         Unknown
# 499     0.3       0     -142   847   705  -121.1851   39.2959         Unknown
#
#     conditionDetails        conditionDate
# 0               None  1970-01-01 00:00:00
# 1               None  1970-01-01 00:00:00
# 2               None  1970-01-01 00:00:00
# 3               None  1970-01-01 00:00:00
# 4               None  1970-01-01 00:00:00
# ..               ...                  ...
# 495             None  1970-01-01 00:00:00
# 496             None  1970-01-01 00:00:00
# 497             None  1970-01-01 00:00:00
# 498             None  1970-01-01 00:00:00
# 499             None  1970-01-01 00:00:00
#
# [500 rows x 18 columns]

# %% [markdown]
# > Adding a column that would help us measure 'best popular' trails...

# %%
trails_dropped['popular_vote'] = trails_dropped['stars']*trails_dropped['starVotes']
trails_dropped
# Out:
#           id                                   name       type  \
# 0    7021990                  Seasonal Wetland Loop       Hike
# 1    7089186                            Nature Loop       Hike
# 2    7023706                   Cosumnes Nature Loop       Hike
# 3    7016942                       Lake Natoma Loop       Hike
# 4    7027546           Traylor Ranch Bird Sanctuary       Hike
# ..       ...                                    ...        ...
# 495  7086303                  Lower Chaparral Trail      Trail
# 496  7000151                        Gray Pine Trail      Trail
# 497  7015046                            Ridge Trail      Trail
# 498  7086306                   Chaparral Loop Trail      Trail
# 499  7023720  Buttermilk Bend Trail Upper Connector  Connector
#
#                                                summary  \
# 0    A scenic loop around one of the wetland areas ...
# 1                A common loop that explores the park.
# 2    A nature-watcher's delight that follows trails...
# 3    Hike around Lake Natoma on bike paths with an ...
# 4    There are lots of birds to see and lots of loo...
# ..                                                 ...
# 495  Beautiful, difficult, and technical. Be cautio...
# 496        Spectacular scenery along a high ridgeline.
# 497  A roller coaster, ridge-top fire road with gre...
# 498  This is a beautiful, albeit difficult trail al...
# 499
#
#                  difficulty  stars  starVotes                   location  \
# 0                      Easy    3.5          2          Davis, California
# 1         Easy/Intermediate    5.0          1     Carmichael, California
# 2                      Easy    4.0          9       Thornton, California
# 3         Easy/Intermediate    4.2          9         Folsom, California
# 4                      Easy    2.0          3         Loomis, California
# ..                      ...    ...        ...                        ...
# 495               Difficult    3.0          1        Clayton, California
# 496            Intermediate    4.0          1        Kenwood, California
# 497  Intermediate/Difficult    3.7          3        Clayton, California
# 498               Difficult    3.0          1        Clayton, California
# 499                    Easy    0.0          0  Lake Wildwood, California
#
#      length  ascent  descent  high   low  longitude  latitude conditionStatus  \
# 0       3.1      10      -12    17    11  -121.6261   38.5505         Unknown
# 1       1.6      21      -20    77    69  -121.3127   38.6168         Unknown
# 2       4.0      88      -84    51     9  -121.4403   38.2657         Unknown
# 3      12.0     293     -294   194   110  -121.1804   38.6766         Unknown
# 4       3.2      65      -65   430   396  -121.2058   38.8485         Unknown
# ..      ...     ...      ...   ...   ...        ...       ...             ...
# 495     0.3       0     -270  1042   772  -121.8650   37.9523         Unknown
# 496     2.6       9    -1399  2711  1321  -122.5092   38.4574         Unknown
# 497     2.9     213     -802  1253   580  -121.8647   37.9509         Unknown
# 498     0.9     211     -381  1169   806  -121.8687   37.9535         Unknown
# 499     0.3       0     -142   847   705  -121.1851   39.2959         Unknown
#
#     conditionDetails        conditionDate  popular_vote
# 0               None  1970-01-01 00:00:00           7.0
# 1               None  1970-01-01 00:00:00           5.0
# 2               None  1970-01-01 00:00:00          36.0
# 3               None  1970-01-01 00:00:00          37.8
# 4               None  1970-01-01 00:00:00           6.0
# ..               ...                  ...           ...
# 495             None  1970-01-01 00:00:00           3.0
# 496             None  1970-01-01 00:00:00           4.0
# 497             None  1970-01-01 00:00:00          11.1
# 498             None  1970-01-01 00:00:00           3.0
# 499             None  1970-01-01 00:00:00           0.0
#
# [500 rows x 19 columns]

# %% [markdown]
# <h2> Step 4: Saving our modified dataframe to CSV. </h2>

# %%
trails_dropped.to_csv('trails_dropped.csv')

# %% [markdown]
# > Additionally, we could further modify based on specific questions from our study....
